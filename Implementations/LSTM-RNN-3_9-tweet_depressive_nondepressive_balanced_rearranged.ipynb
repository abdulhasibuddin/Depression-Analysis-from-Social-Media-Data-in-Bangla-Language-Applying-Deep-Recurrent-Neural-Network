# %%
# Courtesy: https://github.com/mchablani/deep-learning/blob/master/sentiment-rnn/Sentiment_RNN.ipynb
# Depression Analysis in Bangla with LSTM-RNN::
# Two classes with balanced dataset (Total 1968 tweets):
# 1. Depressive (984 tweets)
# 2. Non-depressive (984 tweets)
# 1 depressive -> 1 non-depressive -> 1 depressive -> 1 non-depressive ...

'''
SELECT tweets_depressive_nondepressive_balanced_rearranged.tweet
INTO OUTFILE "D:/EDUCATION/Machine & Deep Learning/Implementations/tweets_depressive_nondepressive_balanced_rearranged_text.txt" 
FROM tweets_depressive_nondepressive_balanced_rearranged;
'''
# Out:
# '\nSELECT tweets_depressive_nondepressive_balanced_rearranged.tweet\nINTO OUTFILE "D:/EDUCATION/Machine & Deep Learning/Implementations/tweets_depressive_nondepressive_balanced_rearranged_text.txt" \nFROM tweets_depressive_nondepressive_balanced_rearranged;\n'

# %%
import numpy as np
import tensorflow as tf
from timeit import default_timer as timer
from collections import Counter
from string import punctuation

# %%
with open('tweets_depressive_nondepressive_balanced_rearranged_text.txt', 'r', encoding="utf8") as f:
    tweets = f.read()
with open('tweets_depressive_nondepressive_balanced_rearranged_labels.txt', 'r', encoding="utf8") as f:
    labels_org = f.read()

# %%
# Data preprocessing::
all_text = ''.join([c for c in tweets if c not in punctuation])
tweets = all_text.split('\n')

all_text = ' '.join(tweets)
words = all_text.split()

# %%
counts = Counter(words)
vocab = sorted(counts, key=counts.get, reverse=True)
vocab_to_int = {word: ii for ii, word in enumerate(vocab, 1)}

tweets_ints = []
for each in tweets:
    tweets_ints.append([vocab_to_int[word] for word in each.split()])

# %%
# Encoding the labels::
list_labels = []

for l in labels_org.split():
    if l == "non_depressive":
        list_labels.append(0)
    elif l == "depressive":
        list_labels.append(1)
        
labels = np.array(list_labels)
#print(len(labels))

# %%
tweets_lens = Counter([len(x) for x in tweets_ints])
print("Zero-length tweets: {}".format(tweets_lens[0]))
print("Maximum tweets length: {}".format(max(tweets_lens)))
# Out:
# Zero-length tweets: 1
# Maximum tweets length: 61

# %%
# Filter out that tweets with 0 length
tweets_ints = [r[0:200] for r in tweets_ints if len(r) > 0]

# %%
from collections import Counter
tweets_lens = Counter([len(x) for x in tweets_ints])
print("Zero-length tweets: {}".format(tweets_lens[0]))
print("Maximum tweet length: {}".format(max(tweets_lens)))
# Out:
# Zero-length tweets: 0
# Maximum tweet length: 61

# %%
seq_len = 200
features = np.zeros((len(tweets_ints), seq_len), dtype=int)
# print(features[:10,:100])
for i, row in enumerate(tweets_ints):
    features[i, -len(row):] = np.array(row)[:seq_len]
#features[:10,:100]

# %%
# 80% training, 10% validation, 10% testing::

split_frac = 0.8

split_index = int(split_frac * len(features))

train_x, val_x = features[:split_index], features[split_index:] 
train_y, val_y = labels[:split_index], labels[split_index:]

split_frac = 0.5
split_index = int(split_frac * len(val_x))

val_x, test_x = val_x[:split_index], val_x[split_index:]
val_y, test_y = val_y[:split_index], val_y[split_index:]

print("\t\t\tFeature Shapes:")
print("Train set: \t\t{}".format(train_x.shape), 
      "\nValidation set: \t{}".format(val_x.shape),
      "\nTest set: \t\t{}".format(test_x.shape))
print("label set: \t\t{}".format(train_y.shape), 
      "\nValidation label set: \t{}".format(val_y.shape),
      "\nTest label set: \t\t{}".format(test_y.shape))
# Out:
# 			Feature Shapes:
# Train set: 		(1574, 200)
# Validation set: 	(197, 200)
# Test set: 		(197, 200)
# label set: 		(1574,)
# Validation label set: 	(197,)
# Test label set: 		(197,)

# %%
# Build the graph::

lstm_size = 128
lstm_layers = 10
batch_size = 1
learning_rate = 0.001

# %%
n_words = len(vocab_to_int) + 1 # Add 1 for 0 added to vocab

# Create the graph object
tf.reset_default_graph()
with tf.name_scope('inputs'):
    inputs_ = tf.placeholder(tf.int32, [None, None], name="inputs")
    labels_ = tf.placeholder(tf.int32, [None, None], name="labels")
    keep_prob = tf.placeholder(tf.float32, name="keep_prob")

# %%
# Size of the embedding vectors (number of units in the embedding layer)
embed_size = 300 

with tf.name_scope("Embeddings"):
    embedding = tf.Variable(tf.random_uniform((n_words, embed_size), -1, 1))
    embed = tf.nn.embedding_lookup(embedding, inputs_)

# %%
def lstm_cell():
    # Your basic LSTM cell
    lstm = tf.contrib.rnn.BasicLSTMCell(lstm_size, reuse=tf.get_variable_scope().reuse)
    # Add dropout to the cell
    return tf.contrib.rnn.DropoutWrapper(lstm, output_keep_prob=keep_prob)

with tf.name_scope("RNN_layers"):
    # Stack up multiple LSTM layers, for deep learning
    cell = tf.contrib.rnn.MultiRNNCell([lstm_cell() for _ in range(lstm_layers)])
    
    # Getting an initial state of all zeros
    initial_state = cell.zero_state(batch_size, tf.float32)

# %%
with tf.name_scope("RNN_forward"):
    outputs, final_state = tf.nn.dynamic_rnn(cell, embed, initial_state=initial_state)

# %%
# Output::

with tf.name_scope('predictions'):
    predictions = tf.contrib.layers.fully_connected(outputs[:, -1], 1, activation_fn=tf.sigmoid)
    tf.summary.histogram('predictions', predictions)
with tf.name_scope('cost'):
    cost = tf.losses.mean_squared_error(labels_, predictions)
    tf.summary.scalar('cost', cost)

with tf.name_scope('train'):
    optimizer = tf.train.AdamOptimizer(learning_rate).minimize(cost)

merged = tf.summary.merge_all()

# %%
# Validation accuracy::

with tf.name_scope('validation'):
    correct_pred = tf.equal(tf.cast(tf.round(predictions), tf.int32), labels_)
    accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32))

# %%
# Batching::

def get_batches(x, y, batch_size=100):
    
    n_batches = len(x)//batch_size
    x, y = x[:n_batches*batch_size], y[:n_batches*batch_size]
    for ii in range(0, len(x), batch_size):
        yield x[ii:ii+batch_size], y[ii:ii+batch_size]

# %%
# Training::

epochs = 10
saver = tf.train.Saver()
start = timer()

with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    train_writer = tf.summary.FileWriter('./logs/tb/train', sess.graph)
    test_writer = tf.summary.FileWriter('./logs/tb/test', sess.graph)
    iteration = 1
    for e in range(epochs):
        state = sess.run(initial_state)
        
        for ii, (x, y) in enumerate(get_batches(train_x, train_y, batch_size), 1):
            feed = {inputs_: x,
                    labels_: y[:, None],
                    keep_prob: 0.5,
                    initial_state: state}
            summary, loss, state, _ = sess.run([merged, cost, final_state, optimizer], feed_dict=feed)
#             loss, state, _ = sess.run([cost, final_state, optimizer], feed_dict=feed)

            train_writer.add_summary(summary, iteration)
        
            if iteration%5==0:
                print("Epoch: {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Train loss: {:.3f}".format(loss))

            if iteration%25==0:
                val_acc = []
                val_state = sess.run(cell.zero_state(batch_size, tf.float32))
                for x, y in get_batches(val_x, val_y, batch_size):
                    feed = {inputs_: x,
                            labels_: y[:, None],
                            keep_prob: 1,
                            initial_state: val_state}
#                     batch_acc, val_state = sess.run([accuracy, final_state], feed_dict=feed)
                    summary, batch_acc, val_state = sess.run([merged, accuracy, final_state], feed_dict=feed)
                    val_acc.append(batch_acc)
                print("Val acc: {:.3f}".format(np.mean(val_acc)))
            iteration +=1
            test_writer.add_summary(summary, iteration)
            saver.save(sess, "checkpoints/tweet_depressive_nondepressive_balanced_2.ckpt")
#            tensorboard = TensorBoard(log_dir="logs/tweet_5000_all_sentiments_six_classes-{}".format(int(time.time())))
    saver.save(sess, "checkpoints/tweet_depressive_nondepressive_balanced_2.ckpt")
    
duration = timer() - start
print('Time elasped =',duration,'sec(s)')
# Out:
# Epoch: 0/10 Iteration: 5 Train loss: 0.257
# Epoch: 0/10 Iteration: 10 Train loss: 0.275
# Epoch: 0/10 Iteration: 15 Train loss: 0.238
# Epoch: 0/10 Iteration: 20 Train loss: 0.295
# Epoch: 0/10 Iteration: 25 Train loss: 0.196
# Val acc: 0.503
# Epoch: 0/10 Iteration: 30 Train loss: 0.184
# Epoch: 0/10 Iteration: 35 Train loss: 0.138
# Epoch: 0/10 Iteration: 40 Train loss: 0.236
# Epoch: 0/10 Iteration: 45 Train loss: 0.764
# Epoch: 0/10 Iteration: 50 Train loss: 0.129
# Val acc: 0.497
# Epoch: 0/10 Iteration: 55 Train loss: 0.179
# Epoch: 0/10 Iteration: 60 Train loss: 0.281
# Epoch: 0/10 Iteration: 65 Train loss: 0.257
# Epoch: 0/10 Iteration: 70 Train loss: 0.611
# Epoch: 0/10 Iteration: 75 Train loss: 0.212
# Val acc: 0.503
# Epoch: 0/10 Iteration: 80 Train loss: 0.509
# Epoch: 0/10 Iteration: 85 Train loss: 0.439
# Epoch: 0/10 Iteration: 90 Train loss: 0.459
# Epoch: 0/10 Iteration: 95 Train loss: 0.276
# Epoch: 0/10 Iteration: 100 Train loss: 0.080
# Val acc: 0.497
# Epoch: 0/10 Iteration: 105 Train loss: 0.308
# Epoch: 0/10 Iteration: 110 Train loss: 0.117
# Epoch: 0/10 Iteration: 115 Train loss: 0.228
# Epoch: 0/10 Iteration: 120 Train loss: 0.343
# Epoch: 0/10 Iteration: 125 Train loss: 0.381
# Val acc: 0.497
# Epoch: 0/10 Iteration: 130 Train loss: 0.252
# Epoch: 0/10 Iteration: 135 Train loss: 0.108
# Epoch: 0/10 Iteration: 140 Train loss: 0.100
# Epoch: 0/10 Iteration: 145 Train loss: 0.266
# Epoch: 0/10 Iteration: 150 Train loss: 0.381
# Val acc: 0.497
# Epoch: 0/10 Iteration: 155 Train loss: 0.421
# Epoch: 0/10 Iteration: 160 Train loss: 0.305
# Epoch: 0/10 Iteration: 165 Train loss: 0.142
# Epoch: 0/10 Iteration: 170 Train loss: 0.182
# Epoch: 0/10 Iteration: 175 Train loss: 0.221
# Val acc: 0.497
# Epoch: 0/10 Iteration: 180 Train loss: 0.392
# Epoch: 2/10 Iteration: 3190 Train loss: 0.198
# Epoch: 2/10 Iteration: 3195 Train loss: 0.331
# Epoch: 2/10 Iteration: 3200 Train loss: 0.191
# Val acc: 0.497
# Epoch: 2/10 Iteration: 3205 Train loss: 0.335
# Epoch: 2/10 Iteration: 3210 Train loss: 0.181
# Epoch: 2/10 Iteration: 3215 Train loss: 0.298
# Epoch: 2/10 Iteration: 3220 Train loss: 0.274
# Epoch: 2/10 Iteration: 3225 Train loss: 0.235
# Val acc: 0.497
# Epoch: 2/10 Iteration: 3230 Train loss: 0.336
# Epoch: 2/10 Iteration: 3235 Train loss: 0.336
# Epoch: 2/10 Iteration: 3240 Train loss: 0.218
# Epoch: 2/10 Iteration: 3245 Train loss: 0.322
# Epoch: 2/10 Iteration: 3250 Train loss: 0.300
# Val acc: 0.497
# Epoch: 2/10 Iteration: 3255 Train loss: 0.353
# Epoch: 2/10 Iteration: 3260 Train loss: 0.344
# Epoch: 2/10 Iteration: 3265 Train loss: 0.294
# Epoch: 2/10 Iteration: 3270 Train loss: 0.313
# Epoch: 2/10 Iteration: 3275 Train loss: 0.142
# Val acc: 0.497
# Epoch: 2/10 Iteration: 3280 Train loss: 0.137
# Epoch: 2/10 Iteration: 3285 Train loss: 0.220
# Epoch: 2/10 Iteration: 3290 Train loss: 0.178
# Epoch: 2/10 Iteration: 3295 Train loss: 0.255
# Epoch: 2/10 Iteration: 3300 Train loss: 0.250
# Val acc: 0.497
# Epoch: 2/10 Iteration: 3305 Train loss: 0.163
# Epoch: 2/10 Iteration: 3310 Train loss: 0.271
# Epoch: 2/10 Iteration: 3315 Train loss: 0.230
# Epoch: 2/10 Iteration: 3320 Train loss: 0.203
# Epoch: 2/10 Iteration: 3325 Train loss: 0.235
# Val acc: 0.497
# Epoch: 2/10 Iteration: 3330 Train loss: 0.246
# Epoch: 2/10 Iteration: 3335 Train loss: 0.242
# Epoch: 2/10 Iteration: 3340 Train loss: 0.263
# Epoch: 2/10 Iteration: 3345 Train loss: 0.094
# Epoch: 2/10 Iteration: 3350 Train loss: 0.241
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-20-6fd7a60d5d09> in <module>()
#      37                             initial_state: val_state}
#      38 #                     batch_acc, val_state = sess.run([accuracy, final_state], feed_dict=feed)
# ---> 39                     summary, batch_acc, val_state = sess.run([merged, accuracy, final_state], feed_dict=feed)
#      40                     val_acc.append(batch_acc)
#      41                 print("Val acc: {:.3f}".format(np.mean(val_acc)))
#
# c:\python36\lib\site-packages\tensorflow\python\client\session.py in run(self, fetches, feed_dict, options, run_metadata)
#     898     try:
#     899       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 900                          run_metadata_ptr)
#     901       if run_metadata:
#     902         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# c:\python36\lib\site-packages\tensorflow\python\client\session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1133     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1134       results = self._do_run(handle, final_targets, final_fetches,
# -> 1135                              feed_dict_tensor, options, run_metadata)
#    1136     else:
#    1137       results = []
#
# c:\python36\lib\site-packages\tensorflow\python\client\session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1314     if handle is None:
#    1315       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1316                            run_metadata)
#    1317     else:
#    1318       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# c:\python36\lib\site-packages\tensorflow\python\client\session.py in _do_call(self, fn, *args)
#    1320   def _do_call(self, fn, *args):
#    1321     try:
# -> 1322       return fn(*args)
#    1323     except errors.OpError as e:
#    1324       message = compat.as_text(e.message)
#
# c:\python36\lib\site-packages\tensorflow\python\client\session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1305       self._extend_graph()
#    1306       return self._call_tf_sessionrun(
# -> 1307           options, feed_dict, fetch_list, target_list, run_metadata)
#    1308
#    1309     def _prun_fn(handle, feed_dict, fetch_list):
#
# c:\python36\lib\site-packages\tensorflow\python\client\session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1407       return tf_session.TF_SessionRun_wrapper(
#    1408           self._session, options, feed_dict, fetch_list, target_list,
# -> 1409           run_metadata)
#    1410     else:
#    1411       with errors.raise_exception_on_not_ok_status() as status:
#
# KeyboardInterrupt:

# %%
# Testing::

test_acc = []
with tf.Session() as sess:
    saver.restore(sess, "checkpoints/tweet_depressive_nondepressive_balanced_2.ckpt")
    test_state = sess.run(cell.zero_state(batch_size, tf.float32))
    for ii, (x, y) in enumerate(get_batches(test_x, test_y, batch_size), 1):
        feed = {inputs_: x,
                labels_: y[:, None],
                keep_prob: 1,
                initial_state: test_state}
        batch_acc, test_state = sess.run([accuracy, final_state], feed_dict=feed)
        test_acc.append(batch_acc)
    print("Test accuracy: {:.3f}".format(np.mean(test_acc)))
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints/tweet_depressive_nondepressive_balanced_2.ckpt
# Test accuracy: 0.503
