# %%
# Courtesy: https://github.com/mchablani/deep-learning/blob/master/sentiment-rnn/Sentiment_RNN.ipynb
# Depression Analysis in Bangla with LSTM-RNN::
# Two classes with balanced dataset (Total 1968 tweets):
# 1. Depressive (984 tweets)
# 2. Non-depressive (984 tweets)
# 1 depressive -> 1 non-depressive -> 1 depressive -> 1 non-depressive ...

'''
SELECT tweets_depressive_nondepressive_balanced_rearranged.tweet
INTO OUTFILE "D:/EDUCATION/Machine & Deep Learning/Implementations/tweets_depressive_nondepressive_balanced_rearranged_text.txt" 
FROM tweets_depressive_nondepressive_balanced_rearranged;
'''
# Out:
# '\nSELECT tweets_depressive_nondepressive_balanced_rearranged.tweet\nINTO OUTFILE "D:/EDUCATION/Machine & Deep Learning/Implementations/tweets_depressive_nondepressive_balanced_rearranged_text.txt" \nFROM tweets_depressive_nondepressive_balanced_rearranged;\n'

# %%
import numpy as np
import tensorflow as tf
from timeit import default_timer as timer
from collections import Counter
from string import punctuation

# %%
with open('tweets_depressive_nondepressive_balanced_rearranged_text.txt', 'r', encoding="utf8") as f:
    tweets = f.read()
with open('tweets_depressive_nondepressive_balanced_rearranged_labels.txt', 'r', encoding="utf8") as f:
    labels_org = f.read()

# %%
# Data preprocessing::
all_text = ''.join([c for c in tweets if c not in punctuation])
tweets = all_text.split('\n')

all_text = ' '.join(tweets)
words = all_text.split()

# %%
counts = Counter(words)
vocab = sorted(counts, key=counts.get, reverse=True)
vocab_to_int = {word: ii for ii, word in enumerate(vocab, 1)}

tweets_ints = []
for each in tweets:
    tweets_ints.append([vocab_to_int[word] for word in each.split()])

# %%
# Encoding the labels::
list_labels = []

for l in labels_org.split():
    if l == "non_depressive":
        list_labels.append(0)
    elif l == "depressive":
        list_labels.append(1)
        
labels = np.array(list_labels)
#print(len(labels))

# %%
tweets_lens = Counter([len(x) for x in tweets_ints])
print("Zero-length tweets: {}".format(tweets_lens[0]))
print("Maximum tweets length: {}".format(max(tweets_lens)))
# Out:
# Zero-length tweets: 1
# Maximum tweets length: 61

# %%
# Filter out that tweets with 0 length
tweets_ints = [r[0:200] for r in tweets_ints if len(r) > 0]

# %%
from collections import Counter
tweets_lens = Counter([len(x) for x in tweets_ints])
print("Zero-length tweets: {}".format(tweets_lens[0]))
print("Maximum tweet length: {}".format(max(tweets_lens)))
# Out:
# Zero-length tweets: 0
# Maximum tweet length: 61

# %%
seq_len = 200
features = np.zeros((len(tweets_ints), seq_len), dtype=int)
# print(features[:10,:100])
for i, row in enumerate(tweets_ints):
    features[i, -len(row):] = np.array(row)[:seq_len]
#features[:10,:100]

# %%
# 80% training, 10% validation, 10% testing::

split_frac = 0.8

split_index = int(split_frac * len(features))

train_x, val_x = features[:split_index], features[split_index:] 
train_y, val_y = labels[:split_index], labels[split_index:]

split_frac = 0.5
split_index = int(split_frac * len(val_x))

val_x, test_x = val_x[:split_index], val_x[split_index:]
val_y, test_y = val_y[:split_index], val_y[split_index:]

print("\t\t\tFeature Shapes:")
print("Train set: \t\t{}".format(train_x.shape), 
      "\nValidation set: \t{}".format(val_x.shape),
      "\nTest set: \t\t{}".format(test_x.shape))
print("label set: \t\t{}".format(train_y.shape), 
      "\nValidation label set: \t{}".format(val_y.shape),
      "\nTest label set: \t\t{}".format(test_y.shape))
# Out:
# 			Feature Shapes:
# Train set: 		(1574, 200)
# Validation set: 	(197, 200)
# Test set: 		(197, 200)
# label set: 		(1574,)
# Validation label set: 	(197,)
# Test label set: 		(197,)

# %%
# Build the graph::

lstm_size = 128
lstm_layers = 5
batch_size = 2
learning_rate = 0.001

# %%
n_words = len(vocab_to_int) + 1 # Add 1 for 0 added to vocab

# Create the graph object
tf.reset_default_graph()
with tf.name_scope('inputs'):
    inputs_ = tf.placeholder(tf.int32, [None, None], name="inputs")
    labels_ = tf.placeholder(tf.int32, [None, None], name="labels")
    keep_prob = tf.placeholder(tf.float32, name="keep_prob")

# %%
# Size of the embedding vectors (number of units in the embedding layer)
embed_size = 300 

with tf.name_scope("Embeddings"):
    embedding = tf.Variable(tf.random_uniform((n_words, embed_size), -1, 1))
    embed = tf.nn.embedding_lookup(embedding, inputs_)

# %%
def lstm_cell():
    # Your basic LSTM cell
    lstm = tf.contrib.rnn.BasicLSTMCell(lstm_size, reuse=tf.get_variable_scope().reuse)
    # Add dropout to the cell
    return tf.contrib.rnn.DropoutWrapper(lstm, output_keep_prob=keep_prob)

with tf.name_scope("RNN_layers"):
    # Stack up multiple LSTM layers, for deep learning
    cell = tf.contrib.rnn.MultiRNNCell([lstm_cell() for _ in range(lstm_layers)])
    
    # Getting an initial state of all zeros
    initial_state = cell.zero_state(batch_size, tf.float32)

# %%
with tf.name_scope("RNN_forward"):
    outputs, final_state = tf.nn.dynamic_rnn(cell, embed, initial_state=initial_state)

# %%
# Output::

with tf.name_scope('predictions'):
    predictions = tf.contrib.layers.fully_connected(outputs[:, -1], 1, activation_fn=tf.sigmoid)
    #predictions = tf.contrib.layers.fully_connected(outputs[:, -1], 1, activation_fn=tf.softmax)
    tf.summary.histogram('predictions', predictions)
with tf.name_scope('cost'):
    cost = tf.losses.mean_squared_error(labels_, predictions)
    tf.summary.scalar('cost', cost)

with tf.name_scope('train'):
    optimizer = tf.train.AdamOptimizer(learning_rate).minimize(cost)

merged = tf.summary.merge_all()

# %%
# Validation accuracy::

with tf.name_scope('validation'):
    correct_pred = tf.equal(tf.cast(tf.round(predictions), tf.int32), labels_)
    accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32))

# %%
# Batching::

def get_batches(x, y, batch_size=100):
    
    n_batches = len(x)//batch_size
    x, y = x[:n_batches*batch_size], y[:n_batches*batch_size]
    for ii in range(0, len(x), batch_size):
        yield x[ii:ii+batch_size], y[ii:ii+batch_size]

# %%
# Training::

epochs = 2
saver = tf.train.Saver()
start = timer()

with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    train_writer = tf.summary.FileWriter('./logs/tb/train', sess.graph)
    test_writer = tf.summary.FileWriter('./logs/tb/test', sess.graph)
    iteration = 1
    for e in range(epochs):
        state = sess.run(initial_state)
        
        for ii, (x, y) in enumerate(get_batches(train_x, train_y, batch_size), 1):
            feed = {inputs_: x,
                    labels_: y[:, None],
                    keep_prob: 0.5,
                    initial_state: state}
            summary, loss, state, _ = sess.run([merged, cost, final_state, optimizer], feed_dict=feed)
#             loss, state, _ = sess.run([cost, final_state, optimizer], feed_dict=feed)

            train_writer.add_summary(summary, iteration)
        
            if iteration%5==0:
                print("Epoch: {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Train loss: {:.3f}".format(loss))

            if iteration%25==0:
                val_acc = []
                val_state = sess.run(cell.zero_state(batch_size, tf.float32))
                for x, y in get_batches(val_x, val_y, batch_size):
                    feed = {inputs_: x,
                            labels_: y[:, None],
                            keep_prob: 1,
                            initial_state: val_state}
#                     batch_acc, val_state = sess.run([accuracy, final_state], feed_dict=feed)
                    summary, batch_acc, val_state = sess.run([merged, accuracy, final_state], feed_dict=feed)
                    val_acc.append(batch_acc)
                print("Val acc: {:.3f}".format(np.mean(val_acc)))
            iteration +=1
            test_writer.add_summary(summary, iteration)
            saver.save(sess, "checkpoints/tweet_depressive_nondepressive_balanced_rearranged.ckpt")
#            tensorboard = TensorBoard(log_dir="logs/tweet_5000_all_sentiments_six_classes-{}".format(int(time.time())))
    saver.save(sess, "checkpoints/tweet_depressive_nondepressive_balanced_rearranged.ckpt")
    
duration = timer() - start
print('Time elasped =',duration,'sec(s)')
# Out:
# Epoch: 0/2 Iteration: 5 Train loss: 0.258
# Epoch: 0/2 Iteration: 10 Train loss: 0.158
# Epoch: 0/2 Iteration: 15 Train loss: 0.254
# Epoch: 0/2 Iteration: 20 Train loss: 0.154
# Epoch: 0/2 Iteration: 25 Train loss: 0.332
# Val acc: 0.510
# Epoch: 0/2 Iteration: 30 Train loss: 0.328
# Epoch: 0/2 Iteration: 35 Train loss: 0.230
# Epoch: 0/2 Iteration: 40 Train loss: 0.217
# Epoch: 0/2 Iteration: 45 Train loss: 0.268
# Epoch: 0/2 Iteration: 50 Train loss: 0.097
# Val acc: 0.515
# Epoch: 0/2 Iteration: 55 Train loss: 0.191
# Epoch: 0/2 Iteration: 60 Train loss: 0.228
# Epoch: 0/2 Iteration: 65 Train loss: 0.263
# Epoch: 0/2 Iteration: 70 Train loss: 0.255
# Epoch: 0/2 Iteration: 75 Train loss: 0.193
# Val acc: 0.515
# Epoch: 0/2 Iteration: 80 Train loss: 0.167
# Epoch: 0/2 Iteration: 85 Train loss: 0.219
# Epoch: 0/2 Iteration: 90 Train loss: 0.271
# Epoch: 0/2 Iteration: 95 Train loss: 0.169
# Epoch: 0/2 Iteration: 100 Train loss: 0.376
# Val acc: 0.520
# Epoch: 0/2 Iteration: 105 Train loss: 0.303
# Epoch: 0/2 Iteration: 110 Train loss: 0.335
# Epoch: 1/2 Iteration: 865 Train loss: 0.231
# Epoch: 1/2 Iteration: 870 Train loss: 0.178
# Epoch: 1/2 Iteration: 875 Train loss: 0.196
# Val acc: 0.577
# Epoch: 1/2 Iteration: 880 Train loss: 0.233
# Epoch: 1/2 Iteration: 885 Train loss: 0.270
# Epoch: 1/2 Iteration: 890 Train loss: 0.283
# Epoch: 1/2 Iteration: 895 Train loss: 0.220
# Epoch: 1/2 Iteration: 900 Train loss: 0.315
# Val acc: 0.500
# Epoch: 1/2 Iteration: 905 Train loss: 0.267
# Epoch: 1/2 Iteration: 910 Train loss: 0.256
# Epoch: 1/2 Iteration: 915 Train loss: 0.327
# Epoch: 1/2 Iteration: 920 Train loss: 0.203
# Epoch: 1/2 Iteration: 925 Train loss: 0.222
# Val acc: 0.571
# Epoch: 1/2 Iteration: 930 Train loss: 0.216
# Epoch: 1/2 Iteration: 935 Train loss: 0.195
# Epoch: 1/2 Iteration: 940 Train loss: 0.267
# Epoch: 1/2 Iteration: 945 Train loss: 0.226
# Epoch: 1/2 Iteration: 950 Train loss: 0.157
# Val acc: 0.531
# Epoch: 1/2 Iteration: 955 Train loss: 0.100
# Epoch: 1/2 Iteration: 960 Train loss: 0.283
# Epoch: 1/2 Iteration: 965 Train loss: 0.291
# Epoch: 1/2 Iteration: 970 Train loss: 0.431
# Epoch: 1/2 Iteration: 975 Train loss: 0.206
# Val acc: 0.592
# Epoch: 1/2 Iteration: 980 Train loss: 0.225
# Epoch: 1/2 Iteration: 985 Train loss: 0.246
# Epoch: 1/2 Iteration: 990 Train loss: 0.234
# Epoch: 1/2 Iteration: 995 Train loss: 0.074
# Epoch: 1/2 Iteration: 1000 Train loss: 0.070
# Val acc: 0.622
# Epoch: 1/2 Iteration: 1005 Train loss: 0.232
# Epoch: 1/2 Iteration: 1010 Train loss: 0.167
# Epoch: 1/2 Iteration: 1015 Train loss: 0.287
# Epoch: 1/2 Iteration: 1020 Train loss: 0.336
# Epoch: 1/2 Iteration: 1025 Train loss: 0.317
# Val acc: 0.628
# Epoch: 1/2 Iteration: 1030 Train loss: 0.232
# Epoch: 1/2 Iteration: 1035 Train loss: 0.130
# Epoch: 1/2 Iteration: 1040 Train loss: 0.288
# Epoch: 1/2 Iteration: 1045 Train loss: 0.295
# Epoch: 1/2 Iteration: 1050 Train loss: 0.099
# Val acc: 0.628
# Epoch: 1/2 Iteration: 1055 Train loss: 0.311
# Epoch: 1/2 Iteration: 1060 Train loss: 0.302
# Epoch: 1/2 Iteration: 1065 Train loss: 0.343
# Epoch: 1/2 Iteration: 1070 Train loss: 0.214
# Epoch: 1/2 Iteration: 1075 Train loss: 0.042
# Val acc: 0.684
# Epoch: 1/2 Iteration: 1080 Train loss: 0.107
# Epoch: 1/2 Iteration: 1085 Train loss: 0.061
# Epoch: 1/2 Iteration: 1090 Train loss: 0.139
# Epoch: 1/2 Iteration: 1095 Train loss: 0.454
# Epoch: 1/2 Iteration: 1100 Train loss: 0.432
# Val acc: 0.704
# Epoch: 1/2 Iteration: 1105 Train loss: 0.570
# Epoch: 1/2 Iteration: 1110 Train loss: 0.099
# Epoch: 1/2 Iteration: 1115 Train loss: 0.076
# Epoch: 1/2 Iteration: 1120 Train loss: 0.302
# Epoch: 1/2 Iteration: 1125 Train loss: 0.441
# Val acc: 0.648
# Epoch: 1/2 Iteration: 1130 Train loss: 0.052
# Epoch: 1/2 Iteration: 1135 Train loss: 0.138
# Epoch: 1/2 Iteration: 1140 Train loss: 0.101
# Epoch: 1/2 Iteration: 1145 Train loss: 0.234
# Epoch: 1/2 Iteration: 1150 Train loss: 0.332
# Val acc: 0.684
# Epoch: 1/2 Iteration: 1155 Train loss: 0.091
# Epoch: 1/2 Iteration: 1160 Train loss: 0.309
# Epoch: 1/2 Iteration: 1165 Train loss: 0.297
# Epoch: 1/2 Iteration: 1170 Train loss: 0.224
# Epoch: 1/2 Iteration: 1175 Train loss: 0.127
# Val acc: 0.684
# Epoch: 1/2 Iteration: 1180 Train loss: 0.142
# Epoch: 1/2 Iteration: 1185 Train loss: 0.463
# Epoch: 1/2 Iteration: 1190 Train loss: 0.165
# Epoch: 1/2 Iteration: 1195 Train loss: 0.111
# Epoch: 1/2 Iteration: 1200 Train loss: 0.147
# Val acc: 0.719
# Epoch: 1/2 Iteration: 1205 Train loss: 0.269
# Epoch: 1/2 Iteration: 1210 Train loss: 0.079
# Epoch: 1/2 Iteration: 1215 Train loss: 0.094
# Epoch: 1/2 Iteration: 1220 Train loss: 0.300
# Epoch: 1/2 Iteration: 1225 Train loss: 0.039
# Val acc: 0.740
# Epoch: 1/2 Iteration: 1230 Train loss: 0.060
# Epoch: 1/2 Iteration: 1235 Train loss: 0.350
# Epoch: 1/2 Iteration: 1240 Train loss: 0.322
# Epoch: 1/2 Iteration: 1245 Train loss: 0.032
# Epoch: 1/2 Iteration: 1250 Train loss: 0.390
# Val acc: 0.770
# Epoch: 1/2 Iteration: 1255 Train loss: 0.019
# Epoch: 1/2 Iteration: 1260 Train loss: 0.313
# Epoch: 1/2 Iteration: 1265 Train loss: 0.279
# Epoch: 1/2 Iteration: 1270 Train loss: 0.335
# Epoch: 1/2 Iteration: 1275 Train loss: 0.122
# Val acc: 0.755
# Epoch: 1/2 Iteration: 1280 Train loss: 0.281
# Epoch: 1/2 Iteration: 1285 Train loss: 0.483
# Epoch: 1/2 Iteration: 1290 Train loss: 0.193
# Epoch: 1/2 Iteration: 1295 Train loss: 0.242
# Epoch: 1/2 Iteration: 1300 Train loss: 0.031
# Val acc: 0.786
# Epoch: 1/2 Iteration: 1305 Train loss: 0.034
# Epoch: 1/2 Iteration: 1310 Train loss: 0.027
# Epoch: 1/2 Iteration: 1315 Train loss: 0.407
# Epoch: 1/2 Iteration: 1320 Train loss: 0.014
# Epoch: 1/2 Iteration: 1325 Train loss: 0.586
# Val acc: 0.760
# Epoch: 1/2 Iteration: 1330 Train loss: 0.053
# Epoch: 1/2 Iteration: 1335 Train loss: 0.606
# Epoch: 1/2 Iteration: 1340 Train loss: 0.420
# Epoch: 1/2 Iteration: 1345 Train loss: 0.378
# Epoch: 1/2 Iteration: 1350 Train loss: 0.106
# Val acc: 0.684
# Epoch: 1/2 Iteration: 1355 Train loss: 0.046
# Epoch: 1/2 Iteration: 1360 Train loss: 0.469
# Epoch: 1/2 Iteration: 1365 Train loss: 0.096
# Epoch: 1/2 Iteration: 1370 Train loss: 0.052
# Epoch: 1/2 Iteration: 1375 Train loss: 0.272
# Val acc: 0.709
# Epoch: 1/2 Iteration: 1380 Train loss: 0.205
# Epoch: 1/2 Iteration: 1385 Train loss: 0.125
# Epoch: 1/2 Iteration: 1390 Train loss: 0.284
# Epoch: 1/2 Iteration: 1395 Train loss: 0.123
# Epoch: 1/2 Iteration: 1400 Train loss: 0.248
# Val acc: 0.760
# Epoch: 1/2 Iteration: 1405 Train loss: 0.271
# Epoch: 1/2 Iteration: 1410 Train loss: 0.148
# Epoch: 1/2 Iteration: 1415 Train loss: 0.283
# Epoch: 1/2 Iteration: 1420 Train loss: 0.255
# Epoch: 1/2 Iteration: 1425 Train loss: 0.172
# Val acc: 0.689
# Epoch: 1/2 Iteration: 1430 Train loss: 0.309
# Epoch: 1/2 Iteration: 1435 Train loss: 0.109
# Epoch: 1/2 Iteration: 1440 Train loss: 0.155
# Epoch: 1/2 Iteration: 1445 Train loss: 0.103
# Epoch: 1/2 Iteration: 1450 Train loss: 0.315
# Val acc: 0.750
# Epoch: 1/2 Iteration: 1455 Train loss: 0.301
# Epoch: 1/2 Iteration: 1460 Train loss: 0.384
# Epoch: 1/2 Iteration: 1465 Train loss: 0.241
# Epoch: 1/2 Iteration: 1470 Train loss: 0.211
# Epoch: 1/2 Iteration: 1475 Train loss: 0.222
# Val acc: 0.673
# Epoch: 1/2 Iteration: 1480 Train loss: 0.420
# Epoch: 1/2 Iteration: 1485 Train loss: 0.257
# Epoch: 1/2 Iteration: 1490 Train loss: 0.204
# Epoch: 1/2 Iteration: 1495 Train loss: 0.102
# Epoch: 1/2 Iteration: 1500 Train loss: 0.500
# Val acc: 0.735
# Epoch: 1/2 Iteration: 1505 Train loss: 0.187
# Epoch: 1/2 Iteration: 1510 Train loss: 0.413
# Epoch: 1/2 Iteration: 1515 Train loss: 0.098
# Epoch: 1/2 Iteration: 1520 Train loss: 0.122
# Epoch: 1/2 Iteration: 1525 Train loss: 0.065
# Val acc: 0.750
# Epoch: 1/2 Iteration: 1530 Train loss: 0.110
# Epoch: 1/2 Iteration: 1535 Train loss: 0.087
# Epoch: 1/2 Iteration: 1540 Train loss: 0.043
# Epoch: 1/2 Iteration: 1545 Train loss: 0.027
# Epoch: 1/2 Iteration: 1550 Train loss: 0.043
# Val acc: 0.776
# Epoch: 1/2 Iteration: 1555 Train loss: 0.097
# Epoch: 1/2 Iteration: 1560 Train loss: 0.057
# Epoch: 1/2 Iteration: 1565 Train loss: 0.068
# Epoch: 1/2 Iteration: 1570 Train loss: 0.031
# Time elasped = 7443.3157842338405 sec(s)

# %%
# Testing::

test_acc = []
with tf.Session() as sess:
    saver.restore(sess, "checkpoints/tweet_depressive_nondepressive_balanced_rearranged.ckpt")
    test_state = sess.run(cell.zero_state(batch_size, tf.float32))
    for ii, (x, y) in enumerate(get_batches(test_x, test_y, batch_size), 1):
        feed = {inputs_: x,
                labels_: y[:, None],
                keep_prob: 1,
                initial_state: test_state}
        batch_acc, test_state = sess.run([accuracy, final_state], feed_dict=feed)
        test_acc.append(batch_acc)
    print("Test accuracy: {:.3f}".format(np.mean(test_acc)))
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints/tweet_depressive_nondepressive_balanced_rearranged.ckpt
# Test accuracy: 0.628
