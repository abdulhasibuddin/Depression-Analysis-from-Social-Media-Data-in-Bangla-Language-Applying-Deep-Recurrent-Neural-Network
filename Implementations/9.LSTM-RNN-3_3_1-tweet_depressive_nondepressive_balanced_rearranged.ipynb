# %%
# Courtesy: https://github.com/mchablani/deep-learning/blob/master/sentiment-rnn/Sentiment_RNN.ipynb
# Depression Analysis in Bangla with LSTM-RNN::
# Two classes with balanced dataset (Total 1968 tweets):
# 1. Depressive (984 tweets)
# 2. Non-depressive (984 tweets)
# 1 depressive -> 1 non-depressive -> 1 depressive -> 1 non-depressive ...

'''
SELECT tweets_depressive_nondepressive.tweet
INTO OUTFILE "D:/EDUCATION/Machine & Deep Learning/Implementations/tweet_depressive_nondepressive_balanced_text.txt" 
FROM tweets_depressive_nondepressive;
'''
# Out:
# '\nSELECT tweets_depressive_nondepressive.tweet\nINTO OUTFILE "D:/EDUCATION/Machine & Deep Learning/Implementations/tweet_depressive_nondepressive_balanced_text.txt" \nFROM tweets_depressive_nondepressive;\n'

# %%
import numpy as np
import tensorflow as tf
from timeit import default_timer as timer
from collections import Counter
from string import punctuation

# %%
with open('tweets_depressive_nondepressive_balanced_rearranged_text.txt', 'r', encoding="utf8") as f:
    tweets = f.read()
with open('tweets_depressive_nondepressive_balanced_rearranged_labels.txt', 'r', encoding="utf8") as f:
    labels_org = f.read()

# %%
# Data preprocessing::
all_text = ''.join([c for c in tweets if c not in punctuation])
tweets = all_text.split('\n')

all_text = ' '.join(tweets)
words = all_text.split()

# %%
counts = Counter(words)
vocab = sorted(counts, key=counts.get, reverse=True)
vocab_to_int = {word: ii for ii, word in enumerate(vocab, 1)}

tweets_ints = []
for each in tweets:
    tweets_ints.append([vocab_to_int[word] for word in each.split()])

# %%
# Encoding the labels::
list_labels = []

for l in labels_org.split():
    if l == "non_depressive":
        list_labels.append(0)
    elif l == "depressive":
        list_labels.append(1)
        
labels = np.array(list_labels)
#print(len(labels))

# %%
tweets_lens = Counter([len(x) for x in tweets_ints])
print("Zero-length tweets: {}".format(tweets_lens[0]))
print("Maximum tweets length: {}".format(max(tweets_lens)))
# Out:
# Zero-length tweets: 1
# Maximum tweets length: 61

# %%
# Filter out that tweets with 0 length
tweets_ints = [r[0:200] for r in tweets_ints if len(r) > 0]

# %%
from collections import Counter
tweets_lens = Counter([len(x) for x in tweets_ints])
print("Zero-length tweets: {}".format(tweets_lens[0]))
print("Maximum tweet length: {}".format(max(tweets_lens)))
# Out:
# Zero-length tweets: 0
# Maximum tweet length: 61

# %%
seq_len = 200
features = np.zeros((len(tweets_ints), seq_len), dtype=int)
# print(features[:10,:100])
for i, row in enumerate(tweets_ints):
    features[i, -len(row):] = np.array(row)[:seq_len]
#features[:10,:100]

# %%
split_frac = 0.8

split_index = int(split_frac * len(features))

train_x, val_x = features[:split_index], features[split_index:] 
train_y, val_y = labels[:split_index], labels[split_index:]

split_frac = 0.5
split_index = int(split_frac * len(val_x))

val_x, test_x = val_x[:split_index], val_x[split_index:]
val_y, test_y = val_y[:split_index], val_y[split_index:]

print("\t\t\tFeature Shapes:")
print("Train set: \t\t{}".format(train_x.shape), 
      "\nValidation set: \t{}".format(val_x.shape),
      "\nTest set: \t\t{}".format(test_x.shape))
print("label set: \t\t{}".format(train_y.shape), 
      "\nValidation label set: \t{}".format(val_y.shape),
      "\nTest label set: \t\t{}".format(test_y.shape))
# Out:
# 			Feature Shapes:
# Train set: 		(1574, 200)
# Validation set: 	(197, 200)
# Test set: 		(197, 200)
# label set: 		(1574,)
# Validation label set: 	(197,)
# Test label set: 		(197,)

# %%
# Build the graph::

lstm_size = 256
lstm_layers = 2
batch_size = 1
learning_rate = 0.001

# %%
n_words = len(vocab_to_int) + 1 # Add 1 for 0 added to vocab

# Create the graph object
tf.reset_default_graph()
with tf.name_scope('inputs'):
    inputs_ = tf.placeholder(tf.int32, [None, None], name="inputs")
    labels_ = tf.placeholder(tf.int32, [None, None], name="labels")
    keep_prob = tf.placeholder(tf.float32, name="keep_prob")

# %%
# Size of the embedding vectors (number of units in the embedding layer)
embed_size = 300 

with tf.name_scope("Embeddings"):
    embedding = tf.Variable(tf.random_uniform((n_words, embed_size), -1, 1))
    embed = tf.nn.embedding_lookup(embedding, inputs_)

# %%
def lstm_cell():
    # Your basic LSTM cell
    lstm = tf.contrib.rnn.BasicLSTMCell(lstm_size, reuse=tf.get_variable_scope().reuse)
    # Add dropout to the cell
    return tf.contrib.rnn.DropoutWrapper(lstm, output_keep_prob=keep_prob)

with tf.name_scope("RNN_layers"):
    # Stack up multiple LSTM layers, for deep learning
    cell = tf.contrib.rnn.MultiRNNCell([lstm_cell() for _ in range(lstm_layers)])
    
    # Getting an initial state of all zeros
    initial_state = cell.zero_state(batch_size, tf.float32)

# %%
with tf.name_scope("RNN_forward"):
    outputs, final_state = tf.nn.dynamic_rnn(cell, embed, initial_state=initial_state)

# %%
# Output::

with tf.name_scope('predictions'):
    predictions = tf.contrib.layers.fully_connected(outputs[:, -1], 1, activation_fn=tf.sigmoid)
    tf.summary.histogram('predictions', predictions)
with tf.name_scope('cost'):
    cost = tf.losses.mean_squared_error(labels_, predictions)
    tf.summary.scalar('cost', cost)

with tf.name_scope('train'):
    optimizer = tf.train.AdamOptimizer(learning_rate).minimize(cost)

merged = tf.summary.merge_all()

# %%
# Validation accuracy::

with tf.name_scope('validation'):
    correct_pred = tf.equal(tf.cast(tf.round(predictions), tf.int32), labels_)
    accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32))

# %%
# Batching::

def get_batches(x, y, batch_size=100):
    
    n_batches = len(x)//batch_size
    x, y = x[:n_batches*batch_size], y[:n_batches*batch_size]
    for ii in range(0, len(x), batch_size):
        yield x[ii:ii+batch_size], y[ii:ii+batch_size]

# %%
# Training::

epochs = 2
saver = tf.train.Saver()
start = timer()

with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    train_writer = tf.summary.FileWriter('./logs/tb/train', sess.graph)
    test_writer = tf.summary.FileWriter('./logs/tb/test', sess.graph)
    iteration = 1
    for e in range(epochs):
        state = sess.run(initial_state)
        
        for ii, (x, y) in enumerate(get_batches(train_x, train_y, batch_size), 1):
            feed = {inputs_: x,
                    labels_: y[:, None],
                    keep_prob: 0.5,
                    initial_state: state}
            summary, loss, state, _ = sess.run([merged, cost, final_state, optimizer], feed_dict=feed)
#             loss, state, _ = sess.run([cost, final_state, optimizer], feed_dict=feed)

            train_writer.add_summary(summary, iteration)
        
            if iteration%5==0:
                print("Epoch: {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Train loss: {:.3f}".format(loss))

            if iteration%25==0:
                val_acc = []
                val_state = sess.run(cell.zero_state(batch_size, tf.float32))
                for x, y in get_batches(val_x, val_y, batch_size):
                    feed = {inputs_: x,
                            labels_: y[:, None],
                            keep_prob: 1,
                            initial_state: val_state}
#                     batch_acc, val_state = sess.run([accuracy, final_state], feed_dict=feed)
                    summary, batch_acc, val_state = sess.run([merged, accuracy, final_state], feed_dict=feed)
                    val_acc.append(batch_acc)
                print("Val acc: {:.3f}".format(np.mean(val_acc)))
            iteration +=1
            test_writer.add_summary(summary, iteration)
            saver.save(sess, "checkpoints/tweet_depressive_nondepressive_balanced_rearranged2.ckpt")
#            tensorboard = TensorBoard(log_dir="logs/tweet_5000_all_sentiments_six_classes-{}".format(int(time.time())))
    saver.save(sess, "checkpoints/tweet_depressive_nondepressive_balanced_rearranged2.ckpt")
    
duration = timer() - start
print('Time elasped =',duration,'sec(s)')
# Out:
# Epoch: 0/2 Iteration: 5 Train loss: 0.323
# Epoch: 0/2 Iteration: 10 Train loss: 0.444
# Epoch: 0/2 Iteration: 15 Train loss: 0.464
# Epoch: 0/2 Iteration: 20 Train loss: 0.004
# Epoch: 0/2 Iteration: 25 Train loss: 0.200
# Val acc: 0.528
# Epoch: 0/2 Iteration: 30 Train loss: 0.446
# Epoch: 0/2 Iteration: 35 Train loss: 0.547
# Epoch: 0/2 Iteration: 40 Train loss: 0.177
# Epoch: 0/2 Iteration: 45 Train loss: 0.647
# Epoch: 0/2 Iteration: 50 Train loss: 0.304
# Val acc: 0.528
# Epoch: 0/2 Iteration: 55 Train loss: 0.530
# Epoch: 0/2 Iteration: 60 Train loss: 0.197
# Epoch: 0/2 Iteration: 65 Train loss: 0.210
# Epoch: 0/2 Iteration: 70 Train loss: 0.056
# Epoch: 0/2 Iteration: 75 Train loss: 0.368
# Val acc: 0.533
# Epoch: 0/2 Iteration: 80 Train loss: 0.235
# Epoch: 0/2 Iteration: 85 Train loss: 0.131
# Epoch: 0/2 Iteration: 90 Train loss: 0.775
# Epoch: 0/2 Iteration: 95 Train loss: 0.337
# Epoch: 0/2 Iteration: 100 Train loss: 0.057
# Val acc: 0.518
# Epoch: 0/2 Iteration: 105 Train loss: 0.414
# Epoch: 0/2 Iteration: 110 Train loss: 0.488
# Epoch: 0/2 Iteration: 115 Train loss: 0.221
# Epoch: 0/2 Iteration: 120 Train loss: 0.333
# Epoch: 0/2 Iteration: 125 Train loss: 0.146
# Val acc: 0.558
# Epoch: 0/2 Iteration: 130 Train loss: 0.339
# Epoch: 0/2 Iteration: 135 Train loss: 0.365
# Epoch: 0/2 Iteration: 140 Train loss: 0.202
# Epoch: 0/2 Iteration: 145 Train loss: 0.147
# Epoch: 0/2 Iteration: 150 Train loss: 0.236
# Val acc: 0.543
# Epoch: 0/2 Iteration: 155 Train loss: 0.372
# Epoch: 0/2 Iteration: 160 Train loss: 0.299
# Epoch: 0/2 Iteration: 165 Train loss: 0.302
# Epoch: 0/2 Iteration: 170 Train loss: 0.428
# Epoch: 0/2 Iteration: 175 Train loss: 0.255
# Val acc: 0.569
# Epoch: 0/2 Iteration: 180 Train loss: 0.406
# Epoch: 0/2 Iteration: 185 Train loss: 0.055
# Epoch: 0/2 Iteration: 190 Train loss: 0.042
# Epoch: 0/2 Iteration: 195 Train loss: 0.573
# Epoch: 0/2 Iteration: 200 Train loss: 0.224
# Val acc: 0.548
# Epoch: 0/2 Iteration: 205 Train loss: 0.612
# Epoch: 0/2 Iteration: 210 Train loss: 0.089
# Epoch: 0/2 Iteration: 215 Train loss: 0.347
# Val acc: 0.604
# Epoch: 0/2 Iteration: 1480 Train loss: 0.095
# Epoch: 0/2 Iteration: 1485 Train loss: 0.358
# Epoch: 0/2 Iteration: 1490 Train loss: 0.010
# Epoch: 0/2 Iteration: 1495 Train loss: 0.124
# Epoch: 0/2 Iteration: 1500 Train loss: 0.572
# Val acc: 0.594
# Epoch: 0/2 Iteration: 1505 Train loss: 0.533
# Epoch: 0/2 Iteration: 1510 Train loss: 0.019
# Epoch: 0/2 Iteration: 1515 Train loss: 0.004
# Epoch: 0/2 Iteration: 1520 Train loss: 0.062
# Epoch: 0/2 Iteration: 1525 Train loss: 0.019
# Val acc: 0.675
# Epoch: 0/2 Iteration: 1530 Train loss: 0.017
# Epoch: 0/2 Iteration: 1535 Train loss: 0.017
# Epoch: 0/2 Iteration: 1540 Train loss: 0.079
# Epoch: 0/2 Iteration: 1545 Train loss: 0.016
# Epoch: 0/2 Iteration: 1550 Train loss: 0.026
# Val acc: 0.670
# Epoch: 0/2 Iteration: 1555 Train loss: 0.007
# Epoch: 0/2 Iteration: 1560 Train loss: 0.597
# Epoch: 0/2 Iteration: 1565 Train loss: 0.148
# Epoch: 0/2 Iteration: 1570 Train loss: 0.094
# Epoch: 1/2 Iteration: 1575 Train loss: 0.021
# Val acc: 0.675
# Epoch: 1/2 Iteration: 1580 Train loss: 0.480
# Epoch: 1/2 Iteration: 1585 Train loss: 0.132
# Epoch: 1/2 Iteration: 1590 Train loss: 0.017
# Epoch: 1/2 Iteration: 1595 Train loss: 0.333
# Epoch: 1/2 Iteration: 1600 Train loss: 0.008
# Val acc: 0.629
# Epoch: 1/2 Iteration: 1605 Train loss: 0.011
# Epoch: 1/2 Iteration: 1610 Train loss: 0.457
# Epoch: 1/2 Iteration: 1615 Train loss: 0.146
# Epoch: 1/2 Iteration: 1620 Train loss: 0.045
# Epoch: 1/2 Iteration: 1625 Train loss: 0.003
# Val acc: 0.695
# Epoch: 1/2 Iteration: 1630 Train loss: 0.055
# Epoch: 1/2 Iteration: 1635 Train loss: 0.002
# Epoch: 1/2 Iteration: 1640 Train loss: 0.108
# Epoch: 1/2 Iteration: 1645 Train loss: 0.001
# Epoch: 1/2 Iteration: 1650 Train loss: 0.000
# Val acc: 0.726
# Epoch: 1/2 Iteration: 1655 Train loss: 0.000
# Epoch: 1/2 Iteration: 1660 Train loss: 0.043
# Epoch: 1/2 Iteration: 1665 Train loss: 0.000
# Epoch: 1/2 Iteration: 1670 Train loss: 0.001
# Epoch: 1/2 Iteration: 1675 Train loss: 0.040
# Val acc: 0.650
# Epoch: 1/2 Iteration: 1680 Train loss: 0.002
# Epoch: 1/2 Iteration: 1685 Train loss: 0.584
# Epoch: 1/2 Iteration: 1690 Train loss: 0.008
# Epoch: 1/2 Iteration: 1695 Train loss: 0.008
# Epoch: 1/2 Iteration: 1700 Train loss: 0.329
# Val acc: 0.670
# Epoch: 1/2 Iteration: 1705 Train loss: 0.005
# Epoch: 1/2 Iteration: 1710 Train loss: 0.784
# Epoch: 1/2 Iteration: 1715 Train loss: 0.009
# Epoch: 1/2 Iteration: 1720 Train loss: 0.547
# Epoch: 1/2 Iteration: 1970 Train loss: 0.052
# Epoch: 1/2 Iteration: 1975 Train loss: 0.015
# Val acc: 0.660
# Epoch: 1/2 Iteration: 1980 Train loss: 0.026
# Epoch: 1/2 Iteration: 1985 Train loss: 0.233
# Epoch: 1/2 Iteration: 1990 Train loss: 0.007
# Epoch: 1/2 Iteration: 1995 Train loss: 0.009
# Epoch: 1/2 Iteration: 2000 Train loss: 0.016
# Val acc: 0.741
# Epoch: 1/2 Iteration: 2005 Train loss: 0.547
# Epoch: 1/2 Iteration: 2010 Train loss: 0.007
# Epoch: 1/2 Iteration: 2015 Train loss: 0.000
# Epoch: 1/2 Iteration: 2020 Train loss: 0.011
# Epoch: 1/2 Iteration: 2025 Train loss: 0.795
# Val acc: 0.685
# Epoch: 1/2 Iteration: 2030 Train loss: 0.026
# Epoch: 1/2 Iteration: 2035 Train loss: 0.808
# Epoch: 1/2 Iteration: 2040 Train loss: 0.008
# Epoch: 1/2 Iteration: 2045 Train loss: 0.180
# Epoch: 1/2 Iteration: 2050 Train loss: 0.010
# Val acc: 0.624
# Epoch: 1/2 Iteration: 2055 Train loss: 0.000
# Epoch: 1/2 Iteration: 2060 Train loss: 0.428
# Epoch: 1/2 Iteration: 2065 Train loss: 0.001
# Epoch: 1/2 Iteration: 2070 Train loss: 0.487
# Epoch: 1/2 Iteration: 2075 Train loss: 0.031
# Val acc: 0.645
# Epoch: 1/2 Iteration: 2080 Train loss: 0.127
# Epoch: 1/2 Iteration: 2085 Train loss: 0.036
# Epoch: 1/2 Iteration: 2090 Train loss: 0.008
# Epoch: 1/2 Iteration: 2095 Train loss: 0.001
# Epoch: 1/2 Iteration: 2100 Train loss: 0.913
# Val acc: 0.640
# Epoch: 1/2 Iteration: 2105 Train loss: 0.447
# Epoch: 1/2 Iteration: 2110 Train loss: 0.236
# Epoch: 1/2 Iteration: 2115 Train loss: 0.119
# Epoch: 1/2 Iteration: 2120 Train loss: 0.553
# Epoch: 1/2 Iteration: 2125 Train loss: 0.037
# Val acc: 0.635
# Epoch: 1/2 Iteration: 2130 Train loss: 0.059
# Epoch: 1/2 Iteration: 2135 Train loss: 0.233
# Epoch: 1/2 Iteration: 2140 Train loss: 0.019
# Epoch: 1/2 Iteration: 2145 Train loss: 0.022
# Epoch: 1/2 Iteration: 2150 Train loss: 0.757
# Val acc: 0.675
# Epoch: 1/2 Iteration: 2155 Train loss: 0.546
# Epoch: 1/2 Iteration: 2160 Train loss: 0.603
# Epoch: 1/2 Iteration: 2165 Train loss: 0.026
# Epoch: 1/2 Iteration: 2170 Train loss: 0.035
# Epoch: 1/2 Iteration: 2175 Train loss: 0.804
# Val acc: 0.589
# Epoch: 1/2 Iteration: 2180 Train loss: 0.013
# Epoch: 1/2 Iteration: 2185 Train loss: 0.364
# Epoch: 1/2 Iteration: 2190 Train loss: 0.259
# Epoch: 1/2 Iteration: 2195 Train loss: 0.002
# Epoch: 1/2 Iteration: 2200 Train loss: 0.051
# Val acc: 0.609
# Epoch: 1/2 Iteration: 2205 Train loss: 0.671
# Epoch: 1/2 Iteration: 2210 Train loss: 0.959
# Epoch: 1/2 Iteration: 2215 Train loss: 0.036
# Epoch: 1/2 Iteration: 2220 Train loss: 0.012
# Epoch: 1/2 Iteration: 2225 Train loss: 0.003
# Val acc: 0.741
# Epoch: 1/2 Iteration: 2230 Train loss: 0.035
# Epoch: 1/2 Iteration: 2235 Train loss: 0.007
# Epoch: 1/2 Iteration: 2240 Train loss: 0.006
# Epoch: 1/2 Iteration: 2245 Train loss: 0.009
# Epoch: 1/2 Iteration: 2250 Train loss: 0.007
# Val acc: 0.711
# Epoch: 1/2 Iteration: 2255 Train loss: 0.001
# Epoch: 1/2 Iteration: 2260 Train loss: 0.365
# Epoch: 1/2 Iteration: 2265 Train loss: 0.002
# Epoch: 1/2 Iteration: 2270 Train loss: 0.506
# Epoch: 1/2 Iteration: 2275 Train loss: 0.000
# Val acc: 0.756
# Epoch: 1/2 Iteration: 2280 Train loss: 0.118
# Epoch: 1/2 Iteration: 2285 Train loss: 0.002
# Epoch: 1/2 Iteration: 2290 Train loss: 0.568
# Epoch: 1/2 Iteration: 2295 Train loss: 0.040
# Epoch: 1/2 Iteration: 2300 Train loss: 0.984
# Val acc: 0.716
# Epoch: 1/2 Iteration: 2305 Train loss: 0.030
# Epoch: 1/2 Iteration: 2310 Train loss: 0.572
# Epoch: 1/2 Iteration: 2315 Train loss: 0.513
# Epoch: 1/2 Iteration: 2320 Train loss: 0.946
# Epoch: 1/2 Iteration: 2325 Train loss: 0.004
# Val acc: 0.761
# Epoch: 1/2 Iteration: 2330 Train loss: 0.020
# Epoch: 1/2 Iteration: 2335 Train loss: 0.003
# Epoch: 1/2 Iteration: 2340 Train loss: 0.827
# Epoch: 1/2 Iteration: 2345 Train loss: 0.006
# Epoch: 1/2 Iteration: 2350 Train loss: 0.002
# Val acc: 0.741
# Epoch: 1/2 Iteration: 2355 Train loss: 0.083
# Epoch: 1/2 Iteration: 2360 Train loss: 0.005
# Epoch: 1/2 Iteration: 2365 Train loss: 0.056
# Epoch: 1/2 Iteration: 2370 Train loss: 0.172
# Epoch: 1/2 Iteration: 2375 Train loss: 0.194
# Val acc: 0.726
# Epoch: 1/2 Iteration: 2380 Train loss: 0.002
# Epoch: 1/2 Iteration: 2385 Train loss: 0.059
# Epoch: 1/2 Iteration: 2390 Train loss: 0.006
# Epoch: 1/2 Iteration: 2395 Train loss: 0.279
# Epoch: 1/2 Iteration: 2400 Train loss: 0.031
# Val acc: 0.766
# Epoch: 1/2 Iteration: 2405 Train loss: 0.016
# Epoch: 1/2 Iteration: 2410 Train loss: 0.382
# Epoch: 1/2 Iteration: 2415 Train loss: 0.143
# Epoch: 1/2 Iteration: 2420 Train loss: 0.004
# Epoch: 1/2 Iteration: 2425 Train loss: 0.364
# Val acc: 0.766
# Epoch: 1/2 Iteration: 2430 Train loss: 0.350
# Epoch: 1/2 Iteration: 2435 Train loss: 0.038
# Epoch: 1/2 Iteration: 2440 Train loss: 0.704
# Epoch: 1/2 Iteration: 2445 Train loss: 0.023
# Epoch: 1/2 Iteration: 2450 Train loss: 0.326
# Val acc: 0.761
# Epoch: 1/2 Iteration: 2455 Train loss: 0.395
# Epoch: 1/2 Iteration: 2460 Train loss: 0.005
# Epoch: 1/2 Iteration: 2465 Train loss: 0.760
# Epoch: 1/2 Iteration: 2470 Train loss: 0.125
# Epoch: 1/2 Iteration: 2475 Train loss: 0.065
# Val acc: 0.756
# Epoch: 1/2 Iteration: 2480 Train loss: 0.043
# Epoch: 1/2 Iteration: 2485 Train loss: 0.060
# Epoch: 1/2 Iteration: 2490 Train loss: 0.004
# Epoch: 1/2 Iteration: 2495 Train loss: 0.189
# Epoch: 1/2 Iteration: 2500 Train loss: 0.849
# Val acc: 0.685
# Epoch: 1/2 Iteration: 2505 Train loss: 0.071
# Epoch: 1/2 Iteration: 2510 Train loss: 0.589
# Epoch: 1/2 Iteration: 2515 Train loss: 0.017
# Epoch: 1/2 Iteration: 2520 Train loss: 0.176
# Epoch: 1/2 Iteration: 2525 Train loss: 0.033
# Val acc: 0.731
# Epoch: 1/2 Iteration: 2530 Train loss: 0.082
# Epoch: 1/2 Iteration: 2535 Train loss: 0.067
# Epoch: 1/2 Iteration: 2540 Train loss: 0.078
# Epoch: 1/2 Iteration: 2545 Train loss: 0.144
# Epoch: 1/2 Iteration: 2550 Train loss: 0.482
# Val acc: 0.807
# Epoch: 1/2 Iteration: 2555 Train loss: 0.036
# Epoch: 1/2 Iteration: 2560 Train loss: 0.006
# Epoch: 1/2 Iteration: 2565 Train loss: 0.070
# Epoch: 1/2 Iteration: 2570 Train loss: 0.361
# Epoch: 1/2 Iteration: 2575 Train loss: 0.018
# Val acc: 0.807
# Epoch: 1/2 Iteration: 2580 Train loss: 0.027
# Epoch: 1/2 Iteration: 2585 Train loss: 0.016
# Epoch: 1/2 Iteration: 2590 Train loss: 0.940
# Epoch: 1/2 Iteration: 2595 Train loss: 0.005
# Epoch: 1/2 Iteration: 2600 Train loss: 0.884
# Val acc: 0.655
# Epoch: 1/2 Iteration: 2605 Train loss: 0.012
# Epoch: 1/2 Iteration: 2610 Train loss: 0.105
# Epoch: 1/2 Iteration: 2615 Train loss: 0.002
# Epoch: 1/2 Iteration: 2620 Train loss: 0.006
# Epoch: 1/2 Iteration: 2625 Train loss: 0.011
# Val acc: 0.716
# Epoch: 1/2 Iteration: 2630 Train loss: 0.140
# Epoch: 1/2 Iteration: 2635 Train loss: 0.063
# Epoch: 1/2 Iteration: 2640 Train loss: 0.027
# Epoch: 1/2 Iteration: 2645 Train loss: 0.073
# Epoch: 1/2 Iteration: 2650 Train loss: 0.258
# Val acc: 0.782
# Epoch: 1/2 Iteration: 2655 Train loss: 0.720
# Epoch: 1/2 Iteration: 2660 Train loss: 0.148
# Epoch: 1/2 Iteration: 2665 Train loss: 0.075
# Epoch: 1/2 Iteration: 2670 Train loss: 0.081
# Epoch: 1/2 Iteration: 2675 Train loss: 0.117
# Val acc: 0.772
# Epoch: 1/2 Iteration: 2680 Train loss: 0.029
# Epoch: 1/2 Iteration: 2685 Train loss: 0.023
# Epoch: 1/2 Iteration: 2690 Train loss: 0.134
# Epoch: 1/2 Iteration: 2695 Train loss: 0.082
# Epoch: 1/2 Iteration: 2700 Train loss: 0.016
# Val acc: 0.706
# Epoch: 1/2 Iteration: 2705 Train loss: 0.046
# Epoch: 1/2 Iteration: 2710 Train loss: 0.005
# Epoch: 1/2 Iteration: 2715 Train loss: 0.033
# Epoch: 1/2 Iteration: 2720 Train loss: 0.011
# Epoch: 1/2 Iteration: 2725 Train loss: 0.001
# Val acc: 0.766
# Epoch: 1/2 Iteration: 2730 Train loss: 0.032
# Epoch: 1/2 Iteration: 2735 Train loss: 0.031
# Epoch: 1/2 Iteration: 2740 Train loss: 0.009
# Epoch: 1/2 Iteration: 2745 Train loss: 0.012
# Epoch: 1/2 Iteration: 2750 Train loss: 0.885
# Val acc: 0.822
# Epoch: 1/2 Iteration: 2755 Train loss: 0.091
# Epoch: 1/2 Iteration: 2760 Train loss: 0.038
# Epoch: 1/2 Iteration: 2765 Train loss: 0.064
# Epoch: 1/2 Iteration: 2770 Train loss: 0.032
# Epoch: 1/2 Iteration: 2775 Train loss: 0.019
# Val acc: 0.817
# Epoch: 1/2 Iteration: 2780 Train loss: 0.018
# Epoch: 1/2 Iteration: 2785 Train loss: 0.021
# Epoch: 1/2 Iteration: 2790 Train loss: 0.015
# Epoch: 1/2 Iteration: 2795 Train loss: 0.007
# Epoch: 1/2 Iteration: 2800 Train loss: 0.021
# Val acc: 0.822
# Epoch: 1/2 Iteration: 2805 Train loss: 0.008
# Epoch: 1/2 Iteration: 2810 Train loss: 0.035
# Epoch: 1/2 Iteration: 2815 Train loss: 0.037
# Epoch: 1/2 Iteration: 2820 Train loss: 0.551
# Epoch: 1/2 Iteration: 2825 Train loss: 0.003
# Val acc: 0.822
# Epoch: 1/2 Iteration: 2830 Train loss: 0.797
# Epoch: 1/2 Iteration: 2835 Train loss: 0.143
# Epoch: 1/2 Iteration: 2840 Train loss: 0.395
# Epoch: 1/2 Iteration: 2845 Train loss: 0.041
# Epoch: 1/2 Iteration: 2850 Train loss: 0.000
# Val acc: 0.822
# Epoch: 1/2 Iteration: 2855 Train loss: 0.297
# Epoch: 1/2 Iteration: 2860 Train loss: 0.061
# Epoch: 1/2 Iteration: 2865 Train loss: 0.014
# Epoch: 1/2 Iteration: 2870 Train loss: 0.023
# Epoch: 1/2 Iteration: 2875 Train loss: 0.391
# Val acc: 0.822
# Epoch: 1/2 Iteration: 2880 Train loss: 0.041
# Epoch: 1/2 Iteration: 2885 Train loss: 0.013
# Epoch: 1/2 Iteration: 2890 Train loss: 0.006
# Epoch: 1/2 Iteration: 2895 Train loss: 0.308
# Epoch: 1/2 Iteration: 2900 Train loss: 0.434
# Val acc: 0.761
# Epoch: 1/2 Iteration: 2905 Train loss: 0.218
# Epoch: 1/2 Iteration: 2910 Train loss: 0.009
# Epoch: 1/2 Iteration: 2915 Train loss: 0.028
# Epoch: 1/2 Iteration: 2920 Train loss: 0.318
# Epoch: 1/2 Iteration: 2925 Train loss: 0.225
# Val acc: 0.792
# Epoch: 1/2 Iteration: 2930 Train loss: 0.207
# Epoch: 1/2 Iteration: 2935 Train loss: 0.003
# Epoch: 1/2 Iteration: 2940 Train loss: 0.474
# Epoch: 1/2 Iteration: 2945 Train loss: 0.017
# Epoch: 1/2 Iteration: 2950 Train loss: 0.004
# Val acc: 0.746
# Epoch: 1/2 Iteration: 2955 Train loss: 0.112
# Epoch: 1/2 Iteration: 2960 Train loss: 0.002
# Epoch: 1/2 Iteration: 2965 Train loss: 0.098
# Epoch: 1/2 Iteration: 2970 Train loss: 0.053
# Epoch: 1/2 Iteration: 2975 Train loss: 0.228
# Val acc: 0.787
# Epoch: 1/2 Iteration: 2980 Train loss: 0.027
# Epoch: 1/2 Iteration: 2985 Train loss: 0.564
# Epoch: 1/2 Iteration: 2990 Train loss: 0.002
# Epoch: 1/2 Iteration: 2995 Train loss: 0.002
# Epoch: 1/2 Iteration: 3000 Train loss: 0.009
# Val acc: 0.766
# Epoch: 1/2 Iteration: 3005 Train loss: 0.008
# Epoch: 1/2 Iteration: 3010 Train loss: 0.547
# Epoch: 1/2 Iteration: 3015 Train loss: 0.007
# Epoch: 1/2 Iteration: 3020 Train loss: 0.001
# Epoch: 1/2 Iteration: 3025 Train loss: 0.051
# Val acc: 0.797
# Epoch: 1/2 Iteration: 3030 Train loss: 0.007
# Epoch: 1/2 Iteration: 3035 Train loss: 0.003
# Epoch: 1/2 Iteration: 3040 Train loss: 0.001
# Epoch: 1/2 Iteration: 3045 Train loss: 0.006
# Epoch: 1/2 Iteration: 3050 Train loss: 0.017
# Val acc: 0.807
# Epoch: 1/2 Iteration: 3055 Train loss: 0.008
# Epoch: 1/2 Iteration: 3060 Train loss: 0.003
# Epoch: 1/2 Iteration: 3065 Train loss: 0.027
# Epoch: 1/2 Iteration: 3070 Train loss: 0.005
# Epoch: 1/2 Iteration: 3075 Train loss: 0.003
# Val acc: 0.797
# Epoch: 1/2 Iteration: 3080 Train loss: 0.001
# Epoch: 1/2 Iteration: 3085 Train loss: 0.039
# Epoch: 1/2 Iteration: 3090 Train loss: 0.001
# Epoch: 1/2 Iteration: 3095 Train loss: 0.405
# Epoch: 1/2 Iteration: 3100 Train loss: 0.001
# Val acc: 0.751
# Epoch: 1/2 Iteration: 3105 Train loss: 0.004
# Epoch: 1/2 Iteration: 3110 Train loss: 0.003
# Epoch: 1/2 Iteration: 3115 Train loss: 0.135
# Epoch: 1/2 Iteration: 3120 Train loss: 0.005
# Epoch: 1/2 Iteration: 3125 Train loss: 0.089
# Val acc: 0.792
# Epoch: 1/2 Iteration: 3130 Train loss: 0.004
# Epoch: 1/2 Iteration: 3135 Train loss: 0.120
# Epoch: 1/2 Iteration: 3140 Train loss: 0.007
# Epoch: 1/2 Iteration: 3145 Train loss: 0.001
# Time elasped = 18656.56631502666 sec(s)

# %%
# Testing::

test_acc = []
with tf.Session() as sess:
    saver.restore(sess, "checkpoints/tweet_depressive_nondepressive_balanced_rearranged2.ckpt")
    test_state = sess.run(cell.zero_state(batch_size, tf.float32))
    for ii, (x, y) in enumerate(get_batches(test_x, test_y, batch_size), 1):
        feed = {inputs_: x,
                labels_: y[:, None],
                keep_prob: 1,
                initial_state: test_state}
        batch_acc, test_state = sess.run([accuracy, final_state], feed_dict=feed)
        test_acc.append(batch_acc)
    print("Test accuracy: {:.3f}".format(np.mean(test_acc)))
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints/tweet_depressive_nondepressive_balanced_rearranged2.ckpt
# Test accuracy: 0.711
