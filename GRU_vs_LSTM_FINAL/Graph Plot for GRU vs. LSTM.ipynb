print(len(lstm_with_unique_9_vLoss))
# Out:
# 75

# %%
# iterations (x-axis):

x_axis_1 = []
for iter_no in range(1,470+1):
    if iter_no%25 == 0:
        x_axis_1.append(iter_no)
x_axis_2 = []
for iter_no in range(1,470+1):
    if iter_no%25 == 0:
        x_axis_2.append(iter_no)
x_axis_3 = []
for iter_no in range(1,470+1):
    if iter_no%25 == 0:
        x_axis_3.append(iter_no)
x_axis_4 = []
for iter_no in range(1,470+1):
    if iter_no%25 == 0:
        x_axis_4.append(iter_no)
x_axis_5 = []
for iter_no in range(1,470+1):
    if iter_no%25 == 0:
        x_axis_5.append(iter_no)
x_axis_6 = []
for iter_no in range(1,90+1):
    if iter_no%25 == 0:
        x_axis_6.append(iter_no)
x_axis_7 = []
for iter_no in range(1,180+1):
    if iter_no%25 == 0:
        x_axis_7.append(iter_no)
x_axis_8 = []
for iter_no in range(1,560+1):
    if iter_no%25 == 0:
        x_axis_8.append(iter_no)
x_axis_9 = []
for iter_no in range(1,1880+1):
    if iter_no%25 == 0:
        x_axis_9.append(iter_no)
x_axis_10 = []
for iter_no in range(1,370+1):
    if iter_no%25 == 0:
        x_axis_10.append(iter_no)
x_axis_11 = []
for iter_no in range(1,185+1):
    if iter_no%25 == 0:
        x_axis_11.append(iter_no)
x_axis_12 = []
for iter_no in range(1,560+1):
    if iter_no%25 == 0:
        x_axis_12.append(iter_no)
x_axis_13 = []
for iter_no in range(1,560+1):
    if iter_no%25 == 0:
        x_axis_13.append(iter_no)
x_axis_14 = []
for iter_no in range(1,1880+1):
    if iter_no%25 == 0:
        x_axis_14.append(iter_no)

# %%
x_list = [x_axis_1,x_axis_2,x_axis_3,x_axis_4,x_axis_5,x_axis_6,x_axis_7,x_axis_8,x_axis_9,x_axis_10,x_axis_11,x_axis_12,x_axis_13,x_axis_14]
list_impl_acc_gru = [gru_unique_1,gru_unique_2,gru_unique_3,gru_unique_4,gru_unique_5,gru_unique_6,gru_unique_7,gru_unique_8,gru_unique_9,gru_unique_10,gru_unique_11,gru_unique_12,gru_unique_13,gru_unique_14]
list_impl_loss_gru = [gru_unique_1_vLoss,
                gru_unique_2_vLoss,
                gru_unique_3_vLoss,
                gru_unique_4_vLoss,
                gru_unique_5_vLoss,
                gru_unique_6_vLoss,
                gru_unique_7_vLoss,
                gru_unique_8_vLoss,
                gru_unique_9_vLoss,
                gru_unique_10_vLoss,
                gru_unique_11_vLoss,
                gru_unique_12_vLoss,
                gru_unique_13_vLoss,
                gru_unique_14_vLoss]
#required_iteration_list = [470,470,470,470,470,90,180,560,1880,370,185,560,560,1880]
#required_epoch_list = [5,5,5,5,5,5,10,3,2,10,5,3,3,10]
#test_acc_list = [59.1,70.0,67.3,74.5,69.1,52.0,61.0,75.7,70.3,57.0,61.0,74.8,69.6,56.5]
###############################################

list_impl_acc_lstm = [lstm_with_unique_1,lstm_with_unique_2,lstm_with_unique_3,lstm_with_unique_4,lstm_with_unique_5,lstm_with_unique_6,lstm_with_unique_7,lstm_with_unique_8,lstm_with_unique_9,lstm_with_unique_10,lstm_with_unique_11,lstm_with_unique_12,lstm_with_unique_13,lstm_with_unique_14]
list_impl_loss_lstm = [lstm_with_unique_1_vLoss,
                 lstm_with_unique_2_vLoss,
                 lstm_with_unique_3_vLoss,
                 lstm_with_unique_4_vLoss,
                 lstm_with_unique_5_vLoss,
                 lstm_with_unique_6_vLoss,
                 lstm_with_unique_7_vLoss,
                 lstm_with_unique_8_vLoss,
                 lstm_with_unique_9_vLoss,
                 lstm_with_unique_10_vLoss,
                 lstm_with_unique_11_vLoss,
                 lstm_with_unique_12_vLoss,
                 lstm_with_unique_13_vLoss,
                 lstm_with_unique_14_vLoss]
#test_acc_list = [50.0,73.6,72.7,69.1,70.9,36.0,59.0,73.9,77.1,57.0,40.0,73.9,42.6,62.6]

# %%
smoothing_factor = 80
linestyle='-.'

for i in range(0,len(x_list)):
    #plt.figure(figsize=(30,15))
    plt.title('GRU vs. LSTM Validation Accuracy for Implementation '+str(i+1))
    plt.xlabel('Iterations')
    plt.ylabel('Validation Accuracy')
    x = x_list[i]

    y = list_impl_acc_gru[i]
    x_sm = np.array(x)
    y_sm = np.array(y)    
    x_smooth = np.linspace(x_sm.min(), x_sm.max(), smoothing_factor)
    y_smooth = spline(x, y, x_smooth)
    plt.plot(x_smooth, y_smooth, marker='o', markersize=2, linestyle=linestyle, label='gru-impl-'+str(i+1))

    y = list_impl_acc_lstm[i]
    x_sm = np.array(x)
    y_sm = np.array(y)    
    x_smooth = np.linspace(x_sm.min(), x_sm.max(), smoothing_factor)
    y_smooth = spline(x, y, x_smooth)
    plt.plot(x_smooth, y_smooth, marker='o', markersize=2, linestyle=linestyle, label='lstm-impl-'+str(i+1))

    #plt.plot(x, y, marker='o', markersize=5, linestyle=linestyle, label=label)

    plt.grid(True)
    plt.legend(loc='upper center', 
               bbox_to_anchor=(0.5, -0.15),
               #prop={'size': 30},
               ncol=2,
               fancybox=True, 
               shadow=True
              )
    plt.savefig('images\compare_image_1_impl_'+str(i+1)+'_validation_accuracy', bbox_inches='tight')
    plt.show()
# Out:
# c:\python36\lib\site-packages\ipykernel_launcher.py:15: DeprecationWarning: `spline` is deprecated!
# spline is deprecated in scipy 0.19.0, use Bspline class instead.
#   from ipykernel import kernelapp as app
# c:\python36\lib\site-packages\ipykernel_launcher.py:22: DeprecationWarning: `spline` is deprecated!
# spline is deprecated in scipy 0.19.0, use Bspline class instead.
# c:\python36\lib\site-packages\scipy\interpolate\interpolate.py:2752: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number5.244205e-17
#   p = scipy.linalg.solve(Q, tmp)

# %%
smoothing_factor = 80
linestyle='-.'

for i in range(0,len(x_list)):
    #plt.figure(figsize=(30,15))
    plt.title('GRU vs. LSTM Validation Loss for Implementation '+str(i+1))
    plt.xlabel('Iterations')
    plt.ylabel('Validation Loss')
    x = x_list[i]

    y = list_impl_loss_gru[i]
    x_sm = np.array(x)
    y_sm = np.array(y)    
    x_smooth = np.linspace(x_sm.min(), x_sm.max(), smoothing_factor)
    y_smooth = spline(x, y, x_smooth)
    plt.plot(x_smooth, y_smooth, marker='o', markersize=2, linestyle=linestyle, label='gru-impl-'+str(i+1))

    y = list_impl_loss_lstm[i]
    x_sm = np.array(x)
    y_sm = np.array(y)    
    x_smooth = np.linspace(x_sm.min(), x_sm.max(), smoothing_factor)
    y_smooth = spline(x, y, x_smooth)
    plt.plot(x_smooth, y_smooth, marker='o', markersize=2, linestyle=linestyle, label='lstm-impl-'+str(i+1))

    #plt.plot(x, y, marker='o', markersize=5, linestyle=linestyle, label=label)

    plt.grid(True)
    plt.legend(loc='upper center', 
               bbox_to_anchor=(0.5, -0.15),
               #prop={'size': 30},
               ncol=2,
               fancybox=True, 
               shadow=True
              )
    plt.savefig('images\compare_image_2_impl_'+str(i+1)+'_validation_loss', bbox_inches='tight')
    plt.show()
# Out:
# c:\python36\lib\site-packages\ipykernel_launcher.py:15: DeprecationWarning: `spline` is deprecated!
# spline is deprecated in scipy 0.19.0, use Bspline class instead.
#   from ipykernel import kernelapp as app
# c:\python36\lib\site-packages\ipykernel_launcher.py:22: DeprecationWarning: `spline` is deprecated!
# spline is deprecated in scipy 0.19.0, use Bspline class instead.

# %%
# GRU 10 FOLD CROSS VALIDATION MODEL ACCURACY::
gru_10_fold_cross_val_folds_acc_list = [0.4435,0.4957,0.7130,0.8609,0.9478,0.9478,0.9565,0.9913,0.9826,1.0000]
gru_10_fold_cross_val_folds_loss_list = [0.0634,0.0009,0.0004,0.0006,0.0002,0.0001,0.0113,0.0001,0.0001,0.0004]
gru_10_fold_cross_val_model_acc = sum(gru_10_fold_cross_val_folds_acc_list)/len(gru_10_fold_cross_val_folds_acc_list)
print('GRY 10 FOLD CROSS VALIDATION MODEL ACCURACY =',gru_10_fold_cross_val_model_acc)
# Out:
# GRY 10 FOLD CROSS VALIDATION MODEL ACCURACY = 0.8339099999999998

# %%
# LSTM 10 FOLD CROSS VALIDATION MODEL ACCURACY::
lstm_10_fold_cross_val_folds_acc_list = [0.4870,0.4696,0.7913,0.8435,0.9565,0.9391,0.9913,0.9826,0.9913,0.9913]
lstm_10_fold_cross_val_folds_loss_list = [0.102,0.020,0.020,0.002,0.003,0.005,0.001,0.000,0.000,0.040]
lstm_10_fold_cross_val_model_acc = sum(lstm_10_fold_cross_val_folds_acc_list)/len(lstm_10_fold_cross_val_folds_acc_list)
print('LSTM 10 FOLD CROSS VALIDATION MODEL ACCURACY =',lstm_10_fold_cross_val_model_acc)
# Out:
# LSTM 10 FOLD CROSS VALIDATION MODEL ACCURACY = 0.84435

# %%
gru_model_8_val_acc = [0.435,0.296,0.348,0.470,0.409,0.409,0.730,0.539,0.374,0.426,0.426,0.513,0.417,0.617,0.678,0.696,0.496,0.487,0.443,0.461,0.539,0.652]
lstm_model_8_val_acc = [0.435,0.496,0.435,0.400,0.426,0.270,0.522,0.504,0.548,0.461,0.426,0.435,0.391,0.504,0.687,0.722,0.443,0.409,0.417,0.435,0.426,0.643]
lstm_model_9_val_acc = [0.475,0.475,0.466,0.517,0.449,0.466,0.466,0.466,0.458,0.398,0.373,0.373,0.449,0.347,0.347,0.381,0.356,0.339,0.322,0.373,0.441,0.356,0.297,0.407,0.432,0.364,0.347,0.356,0.339,0.314,0.305,0.500,0.534,0.661,0.686,0.678,0.695,0.720,0.559,0.661,0.720,0.712,0.551,0.458,0.458,0.432,0.432,0.373,0.347,0.449,0.356,0.415,0.339,0.449,0.432,0.373,0.458,0.458,0.441,0.466,0.508,0.449,0.432,0.466,0.466,0.458,0.466,0.432,0.610,0.703,0.754,0.720,0.619,0.729,0.771]

print(len(gru_model_8_val_acc))
print(len(lstm_model_8_val_acc))
print(len(lstm_model_9_val_acc))
# Out:
# 22
# 22
# 75

# %%
gru_models_test_acc_list = [59.1,70.0,67.3,74.5,69.1,52.0,61.0,75.7,70.3,57.0,61.0,74.8,69.6,56.5]
lstm_models_test_acc_list = [50.0,73.6,72.7,69.1,70.9,36.0,59.0,73.9,77.1,57.0,40.0,73.9,42.6,62.6]

print(len(gru_models_test_acc_list))
print(len(lstm_models_test_acc_list))
# Out:
# 14
# 14

# %%
x_axis_8 = []
iterations_model_8 = 560
for iter_no in range(1,iterations_model_8+1):
    if iter_no%25 == 0:
        x_axis_8.append(iter_no)
        
x_axis_9 = []
iterations_model_9 = 1880
for iter_no in range(1,iterations_model_9+1):
    if iter_no%25 == 0:
        x_axis_9.append(iter_no)

# %%
# set width of bar
barWidth = 0.25
 
# set height of bar
bars1 = gru_models_test_acc_list
bars2 = lstm_models_test_acc_list

# Set position of bar on X axis
r1 = np.arange(len(bars1))
r2 = [x + barWidth for x in r1]

plt.figure(figsize=(15,8))
# Make the plot
plt.bar(r1, bars1, color='#7f6d5f', width=barWidth, edgecolor='white', label='gru-models')
plt.bar(r2, bars2, color='#557f2d', width=barWidth, edgecolor='white', label='lstm-models')

objects = []
for i in range(0,len(gru_models_test_acc_list)):
    object_name = "impl-"+str(i+1)
    objects.append(object_name)

# Add xticks on the middle of the group bars
plt.xlabel('Implementation No.', fontweight='bold')
plt.ylabel('Test Accuracy (%)', fontweight='bold')
plt.xticks([r + barWidth for r in range(len(bars1))], objects)
 
# Create legend & Show graphic
plt.legend()
plt.savefig('images\compare_image_1_gru_vs_lstm_test_acc.png', bbox_inches='tight')
plt.show()

# %%
smoothing_factor = 200
linestyle='-.'
marker = ''
markersize = 3

#plt.figure(figsize=(30,15))
plt.title('GRU vs LSTM Best Model Validation Accuracies')
plt.xlabel('iterations')
plt.ylabel('validation accuracy')

x = x_axis_8
y = gru_model_8_val_acc
plt.plot(x, y, marker=marker, markersize=markersize, linestyle=linestyle, label='gru-model-8(560 iters)')

y = lstm_model_8_val_acc
plt.plot(x, y, marker=marker, markersize=markersize, linestyle=linestyle, label='lstm-model-8(560 iters)')

x = x_axis_9
y = lstm_model_9_val_acc
plt.plot(x, y, marker=marker, markersize=markersize, linestyle=linestyle, label='lstm-model-9(1880 iters)')

plt.grid(True)
plt.legend()
#plt.savefig('images\compare_image_2_gru_vs_lstm_best_models_val_acc.png', bbox_inches='tight')
plt.show()

# %%
smoothing_factor = 200
linestyle='-.'
marker = ''
markersize = 3

#plt.figure(figsize=(30,15))
plt.title('GRU vs LSTM Best Implementation Validation Accuracies')
plt.xlabel('Iterations')
plt.ylabel('Validation Accuracy')

x = x_axis_8
y = gru_model_8_val_acc
x_sm = np.array(x)
y_sm = np.array(y)    
x_smooth = np.linspace(x_sm.min(), x_sm.max(), smoothing_factor)
y_smooth = spline(x, y, x_smooth)
plt.plot(x_smooth, y_smooth, marker=marker, markersize=markersize, linestyle=linestyle, label='gru-impl-8(560 iters)')

y = lstm_model_8_val_acc
x_sm = np.array(x)
y_sm = np.array(y)    
x_smooth = np.linspace(x_sm.min(), x_sm.max(), smoothing_factor)
y_smooth = spline(x, y, x_smooth)
plt.plot(x_smooth, y_smooth, marker=marker, markersize=markersize, linestyle=linestyle, label='lstm-impl-8(560 iters)')

x = x_axis_9
y = lstm_model_9_val_acc
x_sm = np.array(x)
y_sm = np.array(y)    
x_smooth = np.linspace(x_sm.min(), x_sm.max(), smoothing_factor)
y_smooth = spline(x, y, x_smooth)
plt.plot(x_smooth, y_smooth, marker=marker, markersize=markersize, linestyle=linestyle, label='lstm-impl-9(1880 iters)')

plt.grid(True)
plt.legend()
plt.savefig('images\compare_image_3_gru_vs_lstm_best_models_val_acc.png', bbox_inches='tight')
plt.show()
# Out:
# c:\python36\lib\site-packages\ipykernel_launcher.py:16: DeprecationWarning: `spline` is deprecated!
# spline is deprecated in scipy 0.19.0, use Bspline class instead.
#   app.launch_new_instance()
# c:\python36\lib\site-packages\ipykernel_launcher.py:23: DeprecationWarning: `spline` is deprecated!
# spline is deprecated in scipy 0.19.0, use Bspline class instead.
# c:\python36\lib\site-packages\ipykernel_launcher.py:31: DeprecationWarning: `spline` is deprecated!
# spline is deprecated in scipy 0.19.0, use Bspline class instead.

# %%
linestyle='-.'

#plt.figure(figsize=(30,15))
plt.title('GRU vs. LSTM 10 Fold Cross Validation Accuracies')
plt.xlabel('no. of fold')
plt.ylabel('accuracy')

x = [i for i in range (1,len(gru_10_fold_cross_val_folds_acc_list)+1)]
plt.xticks(x)

y = gru_10_fold_cross_val_folds_acc_list
plt.plot(x, y, marker='o', markersize=3, linestyle=linestyle, label='gru-model')

y = lstm_10_fold_cross_val_folds_acc_list
plt.plot(x, y, marker='o', markersize=3, linestyle=linestyle, label='lstm-model')

plt.grid(True)
plt.legend()
#plt.savefig('images\compare_image_1_gru_vs_lstm_10_fold_cross_validation.png', bbox_inches='tight')
plt.show()

# %%
smoothing_factor = 70
linestyle='-.'

#plt.figure(figsize=(30,15))
plt.title('GRU vs. LSTM 10 Fold Cross Validation Accuracy')
plt.xlabel('no. of fold')
plt.ylabel('accuracy')

x = [i for i in range (1,len(gru_10_fold_cross_val_folds_acc_list)+1)]
plt.xticks(x)

y = gru_10_fold_cross_val_folds_acc_list
x_sm = np.array(x)
y_sm = np.array(y)    
x_smooth = np.linspace(x_sm.min(), x_sm.max(), smoothing_factor)
y_smooth = spline(x, y, x_smooth)
plt.plot(x_smooth, y_smooth, marker='', markersize=2, linestyle=linestyle, label='gru')

y = lstm_10_fold_cross_val_folds_acc_list
x_sm = np.array(x)
y_sm = np.array(y)    
x_smooth = np.linspace(x_sm.min(), x_sm.max(), smoothing_factor)
y_smooth = spline(x, y, x_smooth)
plt.plot(x_smooth, y_smooth, marker='', markersize=2, linestyle=linestyle, label='lstm')

plt.grid(True)
plt.legend()
plt.savefig('images\compare_image_4_1_gru_vs_lstm_10_fold_cross_validation_accuracy.png', bbox_inches='tight')
plt.show()
# Out:
# c:\python36\lib\site-packages\ipykernel_launcher.py:16: DeprecationWarning: `spline` is deprecated!
# spline is deprecated in scipy 0.19.0, use Bspline class instead.
#   app.launch_new_instance()
# c:\python36\lib\site-packages\ipykernel_launcher.py:23: DeprecationWarning: `spline` is deprecated!
# spline is deprecated in scipy 0.19.0, use Bspline class instead.

# %%
smoothing_factor = 70
linestyle='-.'
linewidth = 3

plt.figure(figsize=(30,10))
plt.title('GRU vs. LSTM 10 Fold Cross Validation Accuracy', 
          fontsize=45)
plt.xlabel('No. of Fold', 
           fontsize=35)
plt.ylabel('Validation Accuracy', 
           fontsize=35)

x = [i for i in range (1,len(gru_10_fold_cross_val_folds_acc_list)+1)]
plt.xticks(x)

y = gru_10_fold_cross_val_folds_acc_list
x_sm = np.array(x)
y_sm = np.array(y)    
x_smooth = np.linspace(x_sm.min(), x_sm.max(), smoothing_factor)
y_smooth = spline(x, y, x_smooth)
plt.plot(x_smooth, y_smooth, linewidth=linewidth, marker='', markersize=2, linestyle=linestyle, label='gru')

y = lstm_10_fold_cross_val_folds_acc_list
x_sm = np.array(x)
y_sm = np.array(y)    
x_smooth = np.linspace(x_sm.min(), x_sm.max(), smoothing_factor)
y_smooth = spline(x, y, x_smooth)
plt.plot(x_smooth, y_smooth, linewidth=linewidth, marker='', markersize=2, linestyle=linestyle, label='lstm')

plt.grid(True)
plt.legend(loc='upper center', 
           bbox_to_anchor=(0.5, -0.1),
           prop={'size': 30},
           ncol=3,
           fancybox=True, 
           shadow=True
          )
plt.savefig('images\compare_image_4_2_gru_vs_lstm_10_fold_cross_validation_accuracy.png', bbox_inches='tight')
plt.show()
# Out:
# c:\python36\lib\site-packages\ipykernel_launcher.py:20: DeprecationWarning: `spline` is deprecated!
# spline is deprecated in scipy 0.19.0, use Bspline class instead.
# c:\python36\lib\site-packages\ipykernel_launcher.py:27: DeprecationWarning: `spline` is deprecated!
# spline is deprecated in scipy 0.19.0, use Bspline class instead.

# %%
smoothing_factor = 50
linestyle='-.'
#linewidth = 3

#plt.figure(figsize=(30,10))
plt.title('GRU vs. LSTM 10 Fold Cross Validation Loss', 
          fontsize=45)
plt.xlabel('No. of Fold', 
           fontsize=35)
plt.ylabel('Validation Loss', 
           fontsize=35)

x = [i for i in range (1,len(gru_10_fold_cross_val_folds_acc_list)+1)]
plt.xticks(x)

y = gru_10_fold_cross_val_folds_loss_list
x_sm = np.array(x)
y_sm = np.array(y)    
x_smooth = np.linspace(x_sm.min(), x_sm.max(), smoothing_factor)
y_smooth = spline(x, y, x_smooth)
plt.plot(x_smooth, y_smooth, marker='', markersize=2, linestyle=linestyle, label='gru')

y = lstm_10_fold_cross_val_folds_loss_list
x_sm = np.array(x)
y_sm = np.array(y)    
x_smooth = np.linspace(x_sm.min(), x_sm.max(), smoothing_factor)
y_smooth = spline(x, y, x_smooth)
plt.plot(x_smooth, y_smooth, marker='', markersize=2, linestyle=linestyle, label='lstm')

plt.grid(True)
plt.legend()
plt.savefig('images\compare_image_5_1_gru_vs_lstm_10_fold_cross_validation_loss.png', bbox_inches='tight')
plt.show()
# Out:
# c:\python36\lib\site-packages\ipykernel_launcher.py:20: DeprecationWarning: `spline` is deprecated!
# spline is deprecated in scipy 0.19.0, use Bspline class instead.
# c:\python36\lib\site-packages\ipykernel_launcher.py:27: DeprecationWarning: `spline` is deprecated!
# spline is deprecated in scipy 0.19.0, use Bspline class instead.

# %%
smoothing_factor = 50
linestyle='-.'
linewidth = 3

plt.figure(figsize=(30,10))
plt.title('GRU vs. LSTM 10 Fold Cross Validation Loss', 
          fontsize=45)
plt.xlabel('No. of Fold', 
           fontsize=35)
plt.ylabel('Validation Loss', 
           fontsize=35)

x = [i for i in range (1,len(gru_10_fold_cross_val_folds_acc_list)+1)]
plt.xticks(x)

y = gru_10_fold_cross_val_folds_loss_list
x_sm = np.array(x)
y_sm = np.array(y)    
x_smooth = np.linspace(x_sm.min(), x_sm.max(), smoothing_factor)
y_smooth = spline(x, y, x_smooth)
plt.plot(x_smooth, y_smooth, linewidth=linewidth, marker='', markersize=2, linestyle=linestyle, label='gru')

y = lstm_10_fold_cross_val_folds_loss_list
x_sm = np.array(x)
y_sm = np.array(y)    
x_smooth = np.linspace(x_sm.min(), x_sm.max(), smoothing_factor)
y_smooth = spline(x, y, x_smooth)
plt.plot(x_smooth, y_smooth, linewidth=linewidth, marker='', markersize=2, linestyle=linestyle, label='lstm')

plt.grid(True)
plt.legend(loc='upper center', 
           bbox_to_anchor=(0.5, -0.1),
           prop={'size': 30},
           ncol=3,
           fancybox=True, 
           shadow=True
          )
plt.savefig('images\compare_image_5_2_gru_vs_lstm_10_fold_cross_validation_loss.png', bbox_inches='tight')
plt.show()
# Out:
# c:\python36\lib\site-packages\ipykernel_launcher.py:20: DeprecationWarning: `spline` is deprecated!
# spline is deprecated in scipy 0.19.0, use Bspline class instead.
# c:\python36\lib\site-packages\ipykernel_launcher.py:27: DeprecationWarning: `spline` is deprecated!
# spline is deprecated in scipy 0.19.0, use Bspline class instead.
