print(len(gru_unique_9_vLoss))
# Out:
# 75

# %%
print('1->',len(gru_unique_1)==len(gru_unique_1_vLoss))
print('2->',len(gru_unique_2)==len(gru_unique_2_vLoss))
print('3->',len(gru_unique_3)==len(gru_unique_3_vLoss))
print('4->',len(gru_unique_4)==len(gru_unique_4_vLoss))
print('5->',len(gru_unique_5)==len(gru_unique_5_vLoss))
print('6->',len(gru_unique_6)==len(gru_unique_6_vLoss))
print('7->',len(gru_unique_7)==len(gru_unique_7_vLoss))
print('8->',len(gru_unique_8)==len(gru_unique_8_vLoss))
print('9->',len(gru_unique_9)==len(gru_unique_9_vLoss))
print('10->',len(gru_unique_10)==len(gru_unique_10_vLoss))
print('11->',len(gru_unique_11)==len(gru_unique_11_vLoss))
print('12->',len(gru_unique_12)==len(gru_unique_12_vLoss))
print('13->',len(gru_unique_13)==len(gru_unique_13_vLoss))
print('14->',len(gru_unique_14)==len(gru_unique_14_vLoss))
# Out:
# 1-> True
# 2-> True
# 3-> True
# 4-> True
# 5-> True
# 6-> True
# 7-> True
# 8-> True
# 9-> True
# 10-> True
# 11-> True
# 12-> True
# 13-> True
# 14-> True

# %%
# iterations (x-axis):

x_axis_1 = []
for iter_no in range(1,470+1):
    if iter_no%25 == 0:
        x_axis_1.append(iter_no)
x_axis_2 = []
for iter_no in range(1,470+1):
    if iter_no%25 == 0:
        x_axis_2.append(iter_no)
x_axis_3 = []
for iter_no in range(1,470+1):
    if iter_no%25 == 0:
        x_axis_3.append(iter_no)
x_axis_4 = []
for iter_no in range(1,470+1):
    if iter_no%25 == 0:
        x_axis_4.append(iter_no)
x_axis_5 = []
for iter_no in range(1,470+1):
    if iter_no%25 == 0:
        x_axis_5.append(iter_no)
x_axis_6 = []
for iter_no in range(1,90+1):
    if iter_no%25 == 0:
        x_axis_6.append(iter_no)
x_axis_7 = []
for iter_no in range(1,180+1):
    if iter_no%25 == 0:
        x_axis_7.append(iter_no)
x_axis_8 = []
for iter_no in range(1,560+1):
    if iter_no%25 == 0:
        x_axis_8.append(iter_no)
x_axis_9 = []
for iter_no in range(1,1880+1):
    if iter_no%25 == 0:
        x_axis_9.append(iter_no)
x_axis_10 = []
for iter_no in range(1,370+1):
    if iter_no%25 == 0:
        x_axis_10.append(iter_no)
x_axis_11 = []
for iter_no in range(1,185+1):
    if iter_no%25 == 0:
        x_axis_11.append(iter_no)
x_axis_12 = []
for iter_no in range(1,560+1):
    if iter_no%25 == 0:
        x_axis_12.append(iter_no)
x_axis_13 = []
for iter_no in range(1,560+1):
    if iter_no%25 == 0:
        x_axis_13.append(iter_no)
x_axis_14 = []
for iter_no in range(1,1880+1):
    if iter_no%25 == 0:
        x_axis_14.append(iter_no)

# %%
x_list = [x_axis_1,x_axis_2,x_axis_3,x_axis_4,x_axis_5,x_axis_6,x_axis_7,x_axis_8,x_axis_9,x_axis_10,x_axis_11,x_axis_12,x_axis_13,x_axis_14]
list_impl_acc = [gru_unique_1,gru_unique_2,gru_unique_3,gru_unique_4,gru_unique_5,gru_unique_6,gru_unique_7,gru_unique_8,gru_unique_9,gru_unique_10,gru_unique_11,gru_unique_12,gru_unique_13,gru_unique_14]
list_impl_loss = [gru_unique_1_vLoss,
                gru_unique_2_vLoss,
                gru_unique_3_vLoss,
                gru_unique_4_vLoss,
                gru_unique_5_vLoss,
                gru_unique_6_vLoss,
                gru_unique_7_vLoss,
                gru_unique_8_vLoss,
                gru_unique_9_vLoss,
                gru_unique_10_vLoss,
                gru_unique_11_vLoss,
                gru_unique_12_vLoss,
                gru_unique_13_vLoss,
                gru_unique_14_vLoss]
required_iteration_list = [470,470,470,470,470,90,180,560,1880,370,185,560,560,1880]
required_epoch_list = [5,5,5,5,5,5,10,3,2,10,5,3,3,10]
test_acc_list = [59.1,70.0,67.3,74.5,69.1,52.0,61.0,75.7,70.3,57.0,61.0,74.8,69.6,56.5]

print(len(x_list))
print(len(list_impl_acc))
print(len(list_impl_loss))
print(len(required_iteration_list))
print(len(required_epoch_list))
print(len(test_acc_list))
# Out:
# 14
# 14
# 14
# 14
# 14
# 14

# %%
# average validation accuracies:
avg_val_acc_list = []
for model in model_list:
    avg_val_acc_list.append(sum(model)/len(model))
print(len(avg_val_acc_list))
print(avg_val_acc_list)
# Out:
# 14
# [0.49994444444444436, 0.5054444444444444, 0.4828333333333334, 0.47883333333333344, 0.48577777777777775, 0.5266666666666667, 0.5599999999999999, 0.4936818181818181, 0.48190666666666665, 0.5142857142857143, 0.5071428571428571, 0.538, 0.4935909090909089, 0.5696933333333333]

# %%
best_model_val_acc = gru_unique_8
best_model_val_loss = [0.247,0.182,0.202,0.240,0.205,0.265,0.066,0.272,0.192,0.190,0.122,0.254,0.214,0.304,0.195,0.118,0.288,0.033,0.013,0.241,0.152,0.245]

print(len(best_model_val_acc))
print(len(best_model_val_loss))
# Out:
# 22
# 22

# %%
for i in range(0,len(x_list)):
    x_axis_name = 'len(x_axis_'+str(i+1)+') ='
    model_name = '; len(gru_unique_'+str(i+1)+') ='    
    x_axis_length = len(x_list[i])
    model_length = len(model_list[i])
    print(x_axis_name,x_axis_length, model_name,model_length, '; status =',x_axis_length==model_length)
# Out:
# len(x_axis_1) = 18 ; len(gru_unique_1) = 18 ; status = True
# len(x_axis_2) = 18 ; len(gru_unique_2) = 18 ; status = True
# len(x_axis_3) = 18 ; len(gru_unique_3) = 18 ; status = True
# len(x_axis_4) = 18 ; len(gru_unique_4) = 18 ; status = True
# len(x_axis_5) = 18 ; len(gru_unique_5) = 18 ; status = True
# len(x_axis_6) = 3 ; len(gru_unique_6) = 3 ; status = True
# len(x_axis_7) = 7 ; len(gru_unique_7) = 7 ; status = True
# len(x_axis_8) = 22 ; len(gru_unique_8) = 22 ; status = True
# len(x_axis_9) = 75 ; len(gru_unique_9) = 75 ; status = True
# len(x_axis_10) = 14 ; len(gru_unique_10) = 14 ; status = True
# len(x_axis_11) = 7 ; len(gru_unique_11) = 7 ; status = True
# len(x_axis_12) = 22 ; len(gru_unique_12) = 22 ; status = True
# len(x_axis_13) = 22 ; len(gru_unique_13) = 22 ; status = True
# len(x_axis_14) = 75 ; len(gru_unique_14) = 75 ; status = True

# %%
'''
x_axis = x_axis_9
y_axis = []
for i in range(10+1):
    y_axis.append(i/10)
    
print(y_axis)
print(len(x_axis))
print(len(y_axis))
'''
# Out:
# '\nx_axis = x_axis_9\ny_axis = []\nfor i in range(10+1):\n    y_axis.append(i/10)\n    \nprint(y_axis)\nprint(len(x_axis))\nprint(len(y_axis))\n'

# %%
# gru plotting validation accuracies against iterations:

linestyle='-.'
linewidth = 2.5

plt.figure(figsize=(30,15))
plt.title('Validation Accuracies for GRU Models', 
          fontsize=22
         )
plt.xlabel('iterations', 
           fontsize=20
          )
plt.ylabel('validation accuracy', 
           fontsize=20
          )
#plt.plot(x_axis, y_axis_dummy)
#plt.plot(x_axis_dummy, y_axis)
#plt.xticks(x_axis)
#plt.yticks(y_axis)

for i in range(0,len(x_list)):
    label = "impl-"+str(i+1)
    x = x_list[i]
    y = model_list[i]
    plt.plot(x, y, linestyle=linestyle, label=label)
    #plt.plot(x, y, marker='o', markersize=5, linestyle=linestyle, label=label)
    
#plt.axis([min(gru_x_axis),max(gru_x_axis),0,1])
plt.grid(True)
plt.legend(loc='upper center', 
           bbox_to_anchor=(0.5, -0.05),
           prop={'size': 15},
           ncol=14,
           fancybox=True, 
           shadow=True
          )
plt.show()

# %%
# gru plotting validation accuracies against iterations:
smoothing_factor = 200
linestyle='-.'
linewidth = 2.5
legend_properties = {'weight':'bold'}

#plt.savefig('gru_plotting _validation _accuracies _against _iterations.png')
#plt.figure(figsize=(13,8))
#plt.figure(figsize=(25,15))
plt.figure(figsize=(25,17))
plt.title('Validation Accuracies for GRU Model Implementations', 
          fontsize=45
         )
plt.xlabel('iterations', 
           fontsize=35
          )
plt.ylabel('validation accuracy', 
           fontsize=35
          )
'''
x = x_axis_1
y = gru_unique_1
x_sm = np.array(x)
y_sm = np.array(y)
x_smooth = np.linspace(x_sm.min(), x_sm.max(), smoothing_factor)
y_smooth = spline(x, y, x_smooth)
plt.plot(x_smooth, y_smooth, marker='o', linestyle=linestyle, markersize=3, label="gru model 1 smooth")
#plt.plot(x_axis_1, gru_unique_1, marker='o',  markersize=5, label="gru model 1")
'''
#x_list = [x_axis_1,x_axis_2,x_axis_3,x_axis_4,x_axis_5,x_axis_6,x_axis_7,x_axis_8,x_axis_9,x_axis_10,x_axis_11,x_axis_12,x_axis_13,x_axis_14]
#y_list = [gru_unique_1,gru_unique_2,gru_unique_3,gru_unique_4,gru_unique_5,gru_unique_6,gru_unique_7,gru_unique_8,gru_unique_9,gru_unique_10,gru_unique_11,gru_unique_12,gru_unique_13,gru_unique_14]

for i in range(0,len(x_list)):
    label = "impl-"+str(i+1)+" ("+str(required_iteration_list[i])+" iters)"
    x = x_list[i]
    y = model_list[i]
    x_sm = np.array(x)
    y_sm = np.array(y)    
    x_smooth = np.linspace(x_sm.min(), x_sm.max(), smoothing_factor)
    y_smooth = spline(x, y, x_smooth)
    plt.plot(x_smooth, y_smooth, linestyle=linestyle, linewidth=linewidth, label=label)
    #plt.plot(x, y, marker='o', markersize=5, linestyle=linestyle, label=label)

#plt.axis([min(gru_x_axis),max(gru_x_axis),0,1])
plt.grid(True)
#plt.legend(prop=legend_properties)
plt.legend(loc='upper center', 
           bbox_to_anchor=(0.5, -0.05),
           prop={'size': 30},
           ncol=3,
           fancybox=True, 
           shadow=True
          )
plt.savefig('images\gru_image_1_plotting_validation_accuracies_against_iterations.png', bbox_inches='tight')
plt.show()
#plt.savefig('gru_plotting _validation _accuracies _against _iterations.png', bbox_inches='tight')
# Out:
# c:\python36\lib\site-packages\ipykernel_launcher.py:40: DeprecationWarning: `spline` is deprecated!
# spline is deprecated in scipy 0.19.0, use Bspline class instead.
# c:\python36\lib\site-packages\scipy\interpolate\interpolate.py:2752: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number5.244205e-17
#   p = scipy.linalg.solve(Q, tmp)

# %%
# gru best model validation loss vs validation accuracy:

#plt.figure(figsize=(30,15))
plt.title('GRU Model 8 Validation Loss vs. Validation Accuracy')
plt.xlabel('iterations')
plt.ylabel('validation accuracy')
#plt.plot(x_axis, y_axis_dummy)
#plt.plot(x_axis_dummy, y_axis)
#plt.xticks(x_axis)
#plt.yticks(y_axis)

plt.plot(x_axis_8, best_model_val_acc, marker='o', markersize=3, linestyle=linestyle, label='model-8-val-acc')
plt.plot(x_axis_8, best_model_val_loss, marker='o', markersize=3, linestyle=linestyle, label='model-8-val-loss')
#plt.plot(x, y, marker='o', markersize=5, linestyle=linestyle, label=label)
    
#plt.axis([min(gru_x_axis),max(gru_x_axis),0,1])
plt.grid(True)
plt.legend()
#plt.savefig('images\gru_plotting _validation _accuracies _against _iterations.png', bbox_inches='tight')
plt.show()

# %%
smoothing_factor = 50
linestyle='-.'

#plt.figure(figsize=(30,15))
plt.title('Validation Loss vs. Validation Accuracy for GRU Implementation 1')
plt.xlabel('iterations')
plt.ylabel('validation accuracy')
x = x_axis_1

y = gru_unique_1
x_sm = np.array(x)
y_sm = np.array(y)    
x_smooth = np.linspace(x_sm.min(), x_sm.max(), smoothing_factor)
y_smooth = spline(x, y, x_smooth)
plt.plot(x_smooth, y_smooth, marker='o', markersize=3, linestyle=linestyle, label='impl-1-val-acc')

y = gru_unique_1_vLoss
x_sm = np.array(x)
y_sm = np.array(y)    
x_smooth = np.linspace(x_sm.min(), x_sm.max(), smoothing_factor)
y_smooth = spline(x, y, x_smooth)
plt.plot(x_smooth, y_smooth, marker='o', markersize=3, linestyle=linestyle, label='impl-1-val-loss')

#plt.plot(x, y, marker='o', markersize=5, linestyle=linestyle, label=label)

plt.grid(True)
plt.legend(loc='upper center', 
           bbox_to_anchor=(0.5, -0.15),
           #prop={'size': 30},
           ncol=3,
           fancybox=True, 
           shadow=True
          )
plt.savefig('images\gruImages\gru_image_impl_1_validation_loss_vs_validation_accuracy', bbox_inches='tight')
plt.show()
# Out:
# c:\python36\lib\site-packages\ipykernel_launcher.py:14: DeprecationWarning: `spline` is deprecated!
# spline is deprecated in scipy 0.19.0, use Bspline class instead.
#
# c:\python36\lib\site-packages\ipykernel_launcher.py:21: DeprecationWarning: `spline` is deprecated!
# spline is deprecated in scipy 0.19.0, use Bspline class instead.

# %%
smoothing_factor = 50
linestyle='-.'

for i in range(0,len(x_list)):
    #plt.figure(figsize=(30,15))
    plt.title('Validation Loss vs. Validation Accuracy for GRU Implementation '+str(i+1))
    plt.xlabel('iterations')
    plt.ylabel('validation accuracy')
    x = x_list[i]

    y = list_impl_acc[i]
    x_sm = np.array(x)
    y_sm = np.array(y)    
    x_smooth = np.linspace(x_sm.min(), x_sm.max(), smoothing_factor)
    y_smooth = spline(x, y, x_smooth)
    plt.plot(x_smooth, y_smooth, marker='o', markersize=3, linestyle=linestyle, label='impl-'+str(i+1)+'-val-acc')

    y = list_impl_loss[i]
    x_sm = np.array(x)
    y_sm = np.array(y)    
    x_smooth = np.linspace(x_sm.min(), x_sm.max(), smoothing_factor)
    y_smooth = spline(x, y, x_smooth)
    plt.plot(x_smooth, y_smooth, marker='o', markersize=3, linestyle=linestyle, label='impl-'+str(i+1)+'-val-loss')

    #plt.plot(x, y, marker='o', markersize=5, linestyle=linestyle, label=label)

    plt.grid(True)
    plt.legend(loc='upper center', 
               bbox_to_anchor=(0.5, -0.15),
               #prop={'size': 30},
               ncol=3,
               fancybox=True, 
               shadow=True
              )
    plt.savefig('images\gruImages\gru_image_impl_'+str(i+1)+'_validation_loss_vs_validation_accuracy', bbox_inches='tight')
    plt.show()
# Out:
# c:\python36\lib\site-packages\ipykernel_launcher.py:15: DeprecationWarning: `spline` is deprecated!
# spline is deprecated in scipy 0.19.0, use Bspline class instead.
#   from ipykernel import kernelapp as app
# c:\python36\lib\site-packages\ipykernel_launcher.py:22: DeprecationWarning: `spline` is deprecated!
# spline is deprecated in scipy 0.19.0, use Bspline class instead.
# c:\python36\lib\site-packages\scipy\interpolate\interpolate.py:2752: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number5.244205e-17
#   p = scipy.linalg.solve(Q, tmp)

# %%
smoothing_factor = 50
linestyle='-.'

#plt.figure(figsize=(30,15))
plt.title('Validation Loss vs. Validation Accuracy for GRU Implementation 8')
plt.xlabel('iterations')
plt.ylabel('validation accuracy')
x = x_axis_8

y = best_model_val_acc
x_sm = np.array(x)
y_sm = np.array(y)    
x_smooth = np.linspace(x_sm.min(), x_sm.max(), smoothing_factor)
y_smooth = spline(x, y, x_smooth)
plt.plot(x_smooth, y_smooth, marker='o', markersize=3, linestyle=linestyle, label='impl-8-val-acc')

y = best_model_val_loss
x_sm = np.array(x)
y_sm = np.array(y)    
x_smooth = np.linspace(x_sm.min(), x_sm.max(), smoothing_factor)
y_smooth = spline(x, y, x_smooth)
plt.plot(x_smooth, y_smooth, marker='o', markersize=3, linestyle=linestyle, label='impl-8-val-loss')

#plt.plot(x, y, marker='o', markersize=5, linestyle=linestyle, label=label)

plt.grid(True)
plt.legend(loc='upper center', 
           bbox_to_anchor=(0.5, -0.15),
           #prop={'size': 30},
           ncol=3,
           fancybox=True, 
           shadow=True
          )
plt.savefig('images\gru_image_2_best_model_validation_loss_vs_validation_accuracy', bbox_inches='tight')
plt.show()
# Out:
# c:\python36\lib\site-packages\ipykernel_launcher.py:14: DeprecationWarning: `spline` is deprecated!
# spline is deprecated in scipy 0.19.0, use Bspline class instead.
#
# c:\python36\lib\site-packages\ipykernel_launcher.py:21: DeprecationWarning: `spline` is deprecated!
# spline is deprecated in scipy 0.19.0, use Bspline class instead.

# %%
# comparing gru model test accuracies (bar chart):

plt.rcdefaults()
'''
objects = ('Python', 'C++', 'Java', 'Perl', 'Scala', 'Lisp')
y_pos = np.arange(len(objects))
performance = [10,8,6,4,2,1]
'''
plt.figure(figsize=(10,6))
objects = []
for i in range(0,len(model_list)):
    object_name = "impl-"+str(i+1)
    objects.append(object_name)
y_pos = np.arange(len(objects))
performance = test_acc_list ###

for a,b in zip(y_pos, performance):
    plt.text(a, b, str(b)+'%', horizontalalignment='center',verticalalignment='baseline')
    
plt.bar(y_pos, performance, align='center', alpha=0.9)
plt.xticks(y_pos, objects)
#plt.tick_params(axis='both', which='major', labelsize=10)
plt.tick_params(axis='x', which='major', labelsize=7)
plt.xlabel('gru implementation no.')
plt.ylabel('test accuracy (%)')
plt.title('Comparison among GRU Implenentations Test Accuracies')
plt.savefig('images\gru_image_3_comparing_gru_model_test_accuracies_bar_chart.png', bbox_inches='tight')
plt.show()

# %%
# gru_10_fold_cross_validation_on_model_8:
gru_10_fold_cross_val_acc_list = [0.4783,0.4783,0.4435,0.4696,0.5043,0.4957,0.7739,0.6870,0.7130,0.7391,0.8609,0.8609,0.9304,0.9739,0.9478,0.8783,0.8870,0.9478,0.9217,0.9391,0.9565,0.9913,0.9913,0.9913,0.9913,0.9826,0.9826,1.0000,1.0000,1.0000]
gru_10_fold_cross_val_loss_list = [0.1843,0.1090,0.0634,0.1604,0.0079,0.0009,0.0202,0.1773,0.0004,0.0056,0.0000,0.0006,0.1005,0.0000,0.0002,0.0002,0.0000,0.0001,0.0110,0.0002,0.0113,0.9913,0.0001,0.0001,0.0001,0.0000,0.0001,0.0002,0.0668,0.0004]

print(len(gru_10_fold_cross_val_acc_list))
print(len(gru_10_fold_cross_val_loss_list))
# Out:
# 30
# 30

# %%
smoothing_factor = 100
linestyle='-.'

#plt.figure(figsize=(30,15))
plt.title('Validation accuracy vs. Validation Loss for \nApplying 10 Fold Cross Validation on GRU Implementation 8')
plt.xlabel('epochs')
plt.ylabel('accuracy')
x = [i for i in range (1,len(gru_10_fold_cross_val_acc_list)+1)]

y = gru_10_fold_cross_val_acc_list
x_sm = np.array(x)
y_sm = np.array(y)    
x_smooth = np.linspace(x_sm.min(), x_sm.max(), smoothing_factor)
y_smooth = spline(x, y, x_smooth)
plt.plot(x_smooth, y_smooth, marker='', markersize=3, linestyle=linestyle, label='val-acc')

y = gru_10_fold_cross_val_loss_list
x_sm = np.array(x)
y_sm = np.array(y)    
x_smooth = np.linspace(x_sm.min(), x_sm.max(), smoothing_factor)
y_smooth = spline(x, y, x_smooth)
plt.plot(x_smooth, y_smooth, marker='', markersize=3, linestyle=linestyle, label='val-loss')

plt.grid(True)
plt.legend()
plt.savefig('images\gru_image_4_accuracy_vs_loss_for_10_fold_cross_validation.png', bbox_inches='tight')
plt.show()
# Out:
# c:\python36\lib\site-packages\ipykernel_launcher.py:14: DeprecationWarning: `spline` is deprecated!
# spline is deprecated in scipy 0.19.0, use Bspline class instead.
#
# c:\python36\lib\site-packages\ipykernel_launcher.py:21: DeprecationWarning: `spline` is deprecated!
# spline is deprecated in scipy 0.19.0, use Bspline class instead.

# %%
# GRU 10 FOLD CROSS VALIDATION MODEL ACCURACY::
gru_10_fold_cross_val_folds_acc_list = [0.4435,0.4957,0.7130,0.8609,0.9478,0.9478,0.9565,0.9913,0.9826,1.0000]
gru_10_fold_cross_val_model_acc = sum(gru_10_fold_cross_val_folds_acc_list)/len(gru_10_fold_cross_val_folds_acc_list)
print('GRU MODEL - 10 FOLD CROSS VALIDATION ACCURACY =',gru_10_fold_cross_val_model_acc)
# Out:
# GRU MODEL - 10 FOLD CROSS VALIDATION ACCURACY = 0.8339099999999998
