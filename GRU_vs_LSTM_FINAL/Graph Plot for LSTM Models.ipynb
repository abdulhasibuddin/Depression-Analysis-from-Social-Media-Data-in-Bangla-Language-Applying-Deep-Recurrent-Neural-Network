# %%
# Depression Analysis in Bangla with LSTM-RNN RESULTS
# copyright (c) ABDUL HASIB UDDIN <abdulhasibuddin@gmail.com>
# LICENSE: GNU General Public License v3.0

# %%
import matplotlib.pyplot as plt
from scipy.interpolate import spline
import numpy as np

# %%
# LSTM MODEL STATISTICS:

# %%
# lstm validation accuracies:
lstm_with_unique_1 = [0.445,0.409,0.327,0.500,0.464,0.445,0.309,0.500,0.427,0.455,0.500,0.500,0.436,0.445,0.500,0.500,0.455,0.436]
lstm_with_unique_2 = [0.436,0.345,0.273,0.555,0.455,0.436,0.500,0.500,0.436,0.436,0.500,0.482,0.409,0.364,0.727,0.482,0.373,0.545]
lstm_with_unique_3 = [0.445,0.318,0.309,0.491,0.400,0.418,0.500,0.491,0.391,0.400,0.655,0.618,0.436,0.382,0.764,0.491,0.427,0.618]
lstm_with_unique_4 = [0.345,0.336,0.355,0.745,0.336,0.364,0.555,0.609,0.336,0.418,0.736,0.591,0.327,0.455,0.709,0.409,0.391,0.582]
lstm_with_unique_5 = [0.291,0.382,0.473,0.500,0.382,0.355,0.618,0.445,0.482,0.318,0.682,0.445,0.391,0.436,0.600,0.400,0.391,0.400]
lstm_with_unique_6 = [0.500,0.430,0.390]
lstm_with_unique_7 = [0.450,0.420,0.440,0.440,0.560,0.530,0.550]
lstm_with_unique_8 = [0.435,0.496,0.435,0.400,0.426,0.270,0.522,0.504,0.548,0.461,0.426,0.435,0.391,0.504,0.687,0.722,0.443,0.409,0.417,0.435,0.426,0.643]
lstm_with_unique_9 = [0.475,0.475,0.466,0.517,0.449,0.466,0.466,0.466,0.458,0.398,0.373,0.373,0.449,0.347,0.347,0.381,0.356,0.339,0.322,0.373,0.441,0.356,0.297,0.407,0.432,0.364,0.347,0.356,0.339,0.314,0.305,0.500,0.534,0.661,0.686,0.678,0.695,0.720,0.559,0.661,0.720,0.712,0.551,0.458,0.458,0.432,0.432,0.373,0.347,0.449,0.356,0.415,0.339,0.449,0.432,0.373,0.458,0.458,0.441,0.466,0.508,0.449,0.432,0.466,0.466,0.458,0.466,0.432,0.610,0.703,0.754,0.720,0.619,0.729,0.771]
lstm_with_unique_10 = [0.410,0.500,0.500,0.470,0.510,0.410,0.450,0.620,0.660,0.480,0.520,0.550,0.460,0.600]
lstm_with_unique_11 = [0.430,0.400,0.500,0.480,0.510,0.500,0.430]
lstm_with_unique_12 = [0.391,0.435,0.365,0.357,0.426,0.322,0.504,0.487,0.487,0.487,0.426,0.426,0.417,0.530,0.678,0.635,0.504,0.478,0.461,0.487,0.583,0.687]
lstm_with_unique_13 = [0.478,0.470,0.496,0.452,0.417,0.365,0.504,0.530,0.617,0.478,0.478,0.461,0.470,0.504,0.565,0.574,0.452,0.470,0.470,0.470,0.513,0.504]
lstm_with_unique_14 = [0.357,0.426,0.365,0.357,0.391,0.270,0.539,0.496,0.478,0.443,0.409,0.443,0.374,0.504,0.643,0.713,0.461,0.417,0.383,0.426,0.330,0.704,0.626,0.722,0.470,0.409,0.522,0.496,0.704,0.739,0.670,0.635,0.565,0.487,0.609,0.513,0.678,0.748,0.730,0.565,0.539,0.522,0.609,0.600,0.704,0.696,0.583,0.522,0.530,0.539,0.504,0.548,0.687,0.678,0.504,0.557,0.522,0.565,0.617,0.643,0.643,0.557,0.478,0.530,0.548,0.557,0.617,0.661,0.635,0.617,0.548,0.583,0.539,0.591,0.635]

print(len(lstm_with_unique_9))
# Out:
# 75

# %%
# lstm validation loss:
lstm_with_unique_1_vLoss = [0.239,0.246,0.253,0.253,0.241,0.254,0.271,0.251,0.246,0.245,0.253,0.250,0.248,0.242,0.252,0.250,0.244,0.262]
lstm_with_unique_2_vLoss = [0.230,0.245,0.251,0.246,0.238,0.253,0.260,0.249,0.244,0.248,0.242,0.245,0.238,0.238,0.228,0.246,0.226,0.249]
lstm_with_unique_3_vLoss = [0.228,0.250,0.248,0.236,0.241,0.256,0.267,0.243,0.244,0.247,0.225,0.254,0.245,0.220,0.184,0.283,0.219,0.226]
lstm_with_unique_4_vLoss = [0.221,0.246,0.251,0.232,0.240,0.238,0.249,0.234,0.232,0.194,0.205,0.179,0.185,0.144,0.203,0.203,0.226,0.177]
lstm_with_unique_5_vLoss = [0.218,0.236,0.245,0.273,0.212,0.163,0.205,0.253,0.231,0.115,0.188,0.216,0.084,0.125,0.181,0.256,0.123,0.195]
lstm_with_unique_6_vLoss = [0.249,0.245,0.244]
lstm_with_unique_7_vLoss = [0.248,0.244,0.244,0.232,0.277,0.145,0.157]
lstm_with_unique_8_vLoss = [0.245,0.198,0.221,0.251,0.183,0.268,0.205,0.225,0.257,0.238,0.220,0.244,0.226,0.270,0.246,0.227,0.263,0.244,0.240,0.247,0.209,0.184]
lstm_with_unique_9_vLoss = [0.282,0.251,0.283,0.250,0.253,0.202,0.254,0.254,0.358,0.189,0.281,0.243,0.245,0.167,0.224,0.251,0.201,0.137,0.176,0.286,0.329,0.296,0.181,0.280,0.334,0.187,0.194,0.300,0.179,0.298,0.200,0.284,0.080,0.206,0.039,0.118,0.326,0.197,0.280,0.234,0.271,0.265,0.269,0.234,0.243,0.175,0.350,0.246,0.260,0.383,0.082,0.259,0.257,0.118,0.180,0.283,0.002,0.077,0.007,0.306,0.011,0.075,0.490,0.171,0.249,0.049,0.336,0.180,0.192,0.215,0.147,0.124,0.775,0.068,0.150]
lstm_with_unique_10_vLoss = [0.240,0.248,0.246,0.251,0.250,0.244,0.237,0.236,0.153,0.145,0.150,0.141,0.123,0.131]
lstm_with_unique_11_vLoss = [0.240,0.246,0.248,0.254,0.250,0.249,0.242]
lstm_with_unique_12_vLoss = [0.242,0.160,0.201,0.258,0.167,0.256,0.172,0.238,0.261,0.214,0.206,0.210,0.204,0.290,0.231,0.154,0.285,0.206,0.213,0.291,0.091,0.160]
lstm_with_unique_13_vLoss = [0.251,0.238,0.244,0.239,0.234,0.262,0.249,0.251,0.250,0.249,0.248,0.256,0.230,0.257,0.242,0.250,0.251,0.250,0.246,0.236,0.228,0.254]
lstm_with_unique_14_vLoss = [0.244,0.198,0.215,0.253,0.181,0.272,0.205,0.235,0.253,0.237,0.227,0.257,0.223,0.265,0.234,0.231,0.268,0.250,0.235,0.244,0.216,0.205,0.195,0.235,0.189,0.189,0.217,0.127,0.154,0.122,0.193,0.246,0.232,0.210,0.128,0.087,0.231,0.342,0.141,0.211,0.058,0.005,0.173,0.171,0.207,0.039,0.283,0.029,0.016,0.030,0.238,0.149,0.009,0.232,0.005,0.006,0.151,0.001,0.094,0.110,0.001,0.000,0.001,0.001,0.027,0.000,0.038,0.008,0.001,0.182,0.040,0.192,0.005,0.032,0.144]

print(len(lstm_with_unique_9_vLoss))
# Out:
# 75

# %%
print('1->',len(lstm_with_unique_1)==len(lstm_with_unique_1_vLoss))
print('2->',len(lstm_with_unique_2)==len(lstm_with_unique_2_vLoss))
print('3->',len(lstm_with_unique_3)==len(lstm_with_unique_3_vLoss))
print('4->',len(lstm_with_unique_4)==len(lstm_with_unique_4_vLoss))
print('5->',len(lstm_with_unique_5)==len(lstm_with_unique_5_vLoss))
print('6->',len(lstm_with_unique_6)==len(lstm_with_unique_6_vLoss))
print('7->',len(lstm_with_unique_7)==len(lstm_with_unique_7_vLoss))
print('8->',len(lstm_with_unique_8)==len(lstm_with_unique_8_vLoss))
print('9->',len(lstm_with_unique_9)==len(lstm_with_unique_9_vLoss))
print('10->',len(lstm_with_unique_10)==len(lstm_with_unique_10_vLoss))
print('11->',len(lstm_with_unique_11)==len(lstm_with_unique_11_vLoss))
print('12->',len(lstm_with_unique_12)==len(lstm_with_unique_12_vLoss))
print('13->',len(lstm_with_unique_13)==len(lstm_with_unique_13_vLoss))
print('14->',len(lstm_with_unique_14)==len(lstm_with_unique_14_vLoss))
# Out:
# 1-> True
# 2-> True
# 3-> True
# 4-> True
# 5-> True
# 6-> True
# 7-> True
# 8-> True
# 9-> True
# 10-> True
# 11-> True
# 12-> True
# 13-> True
# 14-> True

# %%
# iterations (x-axis):

x_axis_1 = []
for iter_no in range(1,470+1):
    if iter_no%25 == 0:
        x_axis_1.append(iter_no)
x_axis_2 = []
for iter_no in range(1,470+1):
    if iter_no%25 == 0:
        x_axis_2.append(iter_no)
x_axis_3 = []
for iter_no in range(1,470+1):
    if iter_no%25 == 0:
        x_axis_3.append(iter_no)
x_axis_4 = []
for iter_no in range(1,470+1):
    if iter_no%25 == 0:
        x_axis_4.append(iter_no)
x_axis_5 = []
for iter_no in range(1,470+1):
    if iter_no%25 == 0:
        x_axis_5.append(iter_no)
x_axis_6 = []
for iter_no in range(1,90+1):
    if iter_no%25 == 0:
        x_axis_6.append(iter_no)
x_axis_7 = []
for iter_no in range(1,180+1):
    if iter_no%25 == 0:
        x_axis_7.append(iter_no)
x_axis_8 = []
for iter_no in range(1,560+1):
    if iter_no%25 == 0:
        x_axis_8.append(iter_no)
x_axis_9 = []
for iter_no in range(1,1880+1):
    if iter_no%25 == 0:
        x_axis_9.append(iter_no)
x_axis_10 = []
for iter_no in range(1,370+1):
    if iter_no%25 == 0:
        x_axis_10.append(iter_no)
x_axis_11 = []
for iter_no in range(1,185+1):
    if iter_no%25 == 0:
        x_axis_11.append(iter_no)
x_axis_12 = []
for iter_no in range(1,560+1):
    if iter_no%25 == 0:
        x_axis_12.append(iter_no)
x_axis_13 = []
for iter_no in range(1,560+1):
    if iter_no%25 == 0:
        x_axis_13.append(iter_no)
x_axis_14 = []
for iter_no in range(1,1880+1):
    if iter_no%25 == 0:
        x_axis_14.append(iter_no)

# %%
x_list = [x_axis_1,x_axis_2,x_axis_3,x_axis_4,x_axis_5,x_axis_6,x_axis_7,x_axis_8,x_axis_9,x_axis_10,x_axis_11,x_axis_12,x_axis_13,x_axis_14]
list_impl_acc = [lstm_with_unique_1,lstm_with_unique_2,lstm_with_unique_3,lstm_with_unique_4,lstm_with_unique_5,lstm_with_unique_6,lstm_with_unique_7,lstm_with_unique_8,lstm_with_unique_9,lstm_with_unique_10,lstm_with_unique_11,lstm_with_unique_12,lstm_with_unique_13,lstm_with_unique_14]
list_impl_loss = [lstm_with_unique_1_vLoss,
                 lstm_with_unique_2_vLoss,
                 lstm_with_unique_3_vLoss,
                 lstm_with_unique_4_vLoss,
                 lstm_with_unique_5_vLoss,
                 lstm_with_unique_6_vLoss,
                 lstm_with_unique_7_vLoss,
                 lstm_with_unique_8_vLoss,
                 lstm_with_unique_9_vLoss,
                 lstm_with_unique_10_vLoss,
                 lstm_with_unique_11_vLoss,
                 lstm_with_unique_12_vLoss,
                 lstm_with_unique_13_vLoss,
                 lstm_with_unique_14_vLoss]
required_iteration_list = [470,470,470,470,470,90,180,560,1880,370,185,560,560,1880]
required_epoch_list = [5,5,5,5,5,5,10,3,2,10,5,3,3,10]
test_acc_list = [50.0,73.6,72.7,69.1,70.9,36.0,59.0,73.9,77.1,57.0,40.0,73.9,42.6,62.6]

print(len(x_list))
print(len(list_impl_acc))
print(len(list_impl_loss))
print(len(required_iteration_list))
print(len(required_epoch_list))
print(len(test_acc_list))
# Out:
# 14
# 14
# 14
# 14
# 14
# 14

# %%
# average validation accuracies:
avg_val_acc_list = []
for model in model_list:
    avg_val_acc_list.append(sum(model)/len(model))
print(len(avg_val_acc_list))
print(avg_val_acc_list)
# Out:
# 14
# [0.44738888888888895, 0.4585555555555556, 0.4752222222222222, 0.4777222222222222, 0.4439444444444445, 0.43999999999999995, 0.48428571428571426, 0.4743181818181819, 0.4753333333333332, 0.5099999999999999, 0.46428571428571436, 0.4805909090909091, 0.4880909090909091, 0.5496666666666669]

# %%
best_model_val_acc_1 = lstm_with_unique_9 # 77.1%
best_model_val_loss_1 = [0.282,0.251,0.283,0.250,0.253,0.202,0.254,0.254,0.358,0.189,0.281,0.243,0.245,0.167,0.224,0.251,0.201,0.137,0.176,0.286,0.329,0.296,0.181,0.280,0.334,0.187,0.194,0.300,0.179,0.298,0.200,0.284,0.080,0.206,0.039,0.118,0.326,0.197,0.280,0.234,0.271,0.265,0.269,0.234,0.243,0.175,0.350,0.246,0.260,0.383,0.082,0.259,0.257,0.118,0.180,0.283,0.002,0.077,0.007,0.306,0.011,0.075,0.490,0.171,0.249,0.049,0.336,0.180,0.192,0.215,0.147,0.124,0.775,0.068,0.150]
best_model_val_acc_2 = lstm_with_unique_8 # 73.9%
best_model_val_loss_2 = [0.245,0.198,0.221,0.251,0.183,0.268,0.205,0.225,0.257,0.238,0.220,0.244,0.226,0.270,0.246,0.227,0.263,0.244,0.240,0.247,0.209,0.184]

print(len(best_model_val_acc_1))
print(len(best_model_val_loss_1))
print(len(best_model_val_acc_2))
print(len(best_model_val_loss_2))
# Out:
# 75
# 75
# 22
# 22

# %%
for i in range(0,len(x_list)):
    x_axis_name = 'len(x_axis_'+str(i+1)+') ='
    model_name = '; len(lstm_with_unique_'+str(i+1)+') ='    
    x_axis_length = len(x_list[i])
    model_length = len(model_list[i])
    print(x_axis_name,x_axis_length, model_name,model_length, '; status =',x_axis_length==model_length)
# Out:
# len(x_axis_1) = 18 ; len(lstm_with_unique_1) = 18 ; status = True
# len(x_axis_2) = 18 ; len(lstm_with_unique_2) = 18 ; status = True
# len(x_axis_3) = 18 ; len(lstm_with_unique_3) = 18 ; status = True
# len(x_axis_4) = 18 ; len(lstm_with_unique_4) = 18 ; status = True
# len(x_axis_5) = 18 ; len(lstm_with_unique_5) = 18 ; status = True
# len(x_axis_6) = 3 ; len(lstm_with_unique_6) = 3 ; status = True
# len(x_axis_7) = 7 ; len(lstm_with_unique_7) = 7 ; status = True
# len(x_axis_8) = 22 ; len(lstm_with_unique_8) = 22 ; status = True
# len(x_axis_9) = 75 ; len(lstm_with_unique_9) = 75 ; status = True
# len(x_axis_10) = 14 ; len(lstm_with_unique_10) = 14 ; status = True
# len(x_axis_11) = 7 ; len(lstm_with_unique_11) = 7 ; status = True
# len(x_axis_12) = 22 ; len(lstm_with_unique_12) = 22 ; status = True
# len(x_axis_13) = 22 ; len(lstm_with_unique_13) = 22 ; status = True
# len(x_axis_14) = 75 ; len(lstm_with_unique_14) = 75 ; status = True

# %%
# lstm plotting validation accuracies against iterations:

linestyle='-.'
linewidth = 2.5

plt.figure(figsize=(25,17))
plt.title('Validation Accuracies for LSTM Models')
plt.xlabel('iterations')
plt.ylabel('validation accuracy')

for i in range(0,len(x_list)):
    label = "impl-"+str(i+1)
    x = x_list[i]
    y = model_list[i]
    plt.plot(x, y, linestyle=linestyle, label=label)
    
plt.grid(True)
plt.legend(loc='upper center', 
           bbox_to_anchor=(0.5, -0.05),
           prop={'size': 30},
           ncol=3,
           fancybox=True, 
           shadow=True
          )
plt.show()

# %%
# lstm plotting validation accuracies against iterations:
smoothing_factor = 200
linestyle='-.'
linewidth = 2.5

#plt.figure(figsize=(13,8))
plt.figure(figsize=(25,17))
plt.title('Validation Accuracies for LSTM Model Implementations', 
          fontsize=45
         )
plt.xlabel('iterations', 
           fontsize=35
          )
plt.ylabel('validation accuracy', 
           fontsize=35
          )

for i in range(0,len(x_list)):
    label = "impl-"+str(i+1)+" ("+str(required_iteration_list[i])+" iters)"
    x = x_list[i]
    y = model_list[i]
    x_sm = np.array(x)
    y_sm = np.array(y)    
    x_smooth = np.linspace(x_sm.min(), x_sm.max(), smoothing_factor)
    y_smooth = spline(x, y, x_smooth)
    plt.plot(x_smooth, y_smooth, linestyle=linestyle, linewidth=linewidth, label=label)
    
plt.grid(True)
plt.legend(loc='upper center', 
           bbox_to_anchor=(0.5, -0.05),
           prop={'size': 30},
           ncol=3,
           fancybox=True, 
           shadow=True
          )
plt.savefig('images\lstm_image_1_plotting_validation_accuracies_against_iterations.png', bbox_inches='tight')
plt.show()
# Out:
# c:\python36\lib\site-packages\ipykernel_launcher.py:25: DeprecationWarning: `spline` is deprecated!
# spline is deprecated in scipy 0.19.0, use Bspline class instead.
# c:\python36\lib\site-packages\scipy\interpolate\interpolate.py:2752: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number5.244205e-17
#   p = scipy.linalg.solve(Q, tmp)

# %%
# lstm best model validation loss vs validation accuracy:

#plt.figure(figsize=(30,15))
plt.title('LSTM Implementation 8 Validation Loss vs. Validation Accuracy')
plt.xlabel('iterations')
plt.ylabel('validation accuracy')

plt.plot(x_axis_8, best_model_val_acc_2, marker='o', markersize=3, linestyle=linestyle, label='impl-8-val-acc')
plt.plot(x_axis_8, best_model_val_loss_2, marker='o', markersize=3, linestyle=linestyle, label='impl-8-val-loss')
    
plt.grid(True)
plt.legend()
plt.show()

# %%
smoothing_factor = 50
linestyle='-.'

for i in range(0,len(x_list)):
    #plt.figure(figsize=(30,15))
    plt.title('Validation Loss vs. Validation Accuracy for LSTM Implementation '+str(i+1))
    plt.xlabel('iterations')
    plt.ylabel('validation accuracy')
    x = x_list[i]

    y = list_impl_acc[i]
    x_sm = np.array(x)
    y_sm = np.array(y)    
    x_smooth = np.linspace(x_sm.min(), x_sm.max(), smoothing_factor)
    y_smooth = spline(x, y, x_smooth)
    plt.plot(x_smooth, y_smooth, marker='o', markersize=3, linestyle=linestyle, label='impl-'+str(i+1)+'-val-acc')

    y = list_impl_loss[i]
    x_sm = np.array(x)
    y_sm = np.array(y)    
    x_smooth = np.linspace(x_sm.min(), x_sm.max(), smoothing_factor)
    y_smooth = spline(x, y, x_smooth)
    plt.plot(x_smooth, y_smooth, marker='o', markersize=3, linestyle=linestyle, label='impl-'+str(i+1)+'-val-loss')

    #plt.plot(x, y, marker='o', markersize=5, linestyle=linestyle, label=label)

    plt.grid(True)
    plt.legend(loc='upper center', 
               bbox_to_anchor=(0.5, -0.15),
               #prop={'size': 30},
               ncol=3,
               fancybox=True, 
               shadow=True
              )
    plt.savefig('images\lstmImages\lstm_image_impl_'+str(i+1)+'_validation_loss_vs_validation_accuracy', bbox_inches='tight')
    plt.show()
# Out:
# c:\python36\lib\site-packages\ipykernel_launcher.py:15: DeprecationWarning: `spline` is deprecated!
# spline is deprecated in scipy 0.19.0, use Bspline class instead.
#   from ipykernel import kernelapp as app
# c:\python36\lib\site-packages\ipykernel_launcher.py:22: DeprecationWarning: `spline` is deprecated!
# spline is deprecated in scipy 0.19.0, use Bspline class instead.
# c:\python36\lib\site-packages\scipy\interpolate\interpolate.py:2752: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number5.244205e-17
#   p = scipy.linalg.solve(Q, tmp)

# %%
smoothing_factor = 50
linestyle='-.'

#plt.figure(figsize=(30,15))
plt.title('Validation Loss vs. Validation Accuracy for LSTM Implementation 9')
plt.xlabel('iterations')
plt.ylabel('validation accuracy')
x = x_axis_9

y = best_model_val_acc_1
x_sm = np.array(x)
y_sm = np.array(y)    
x_smooth = np.linspace(x_sm.min(), x_sm.max(), smoothing_factor)
y_smooth = spline(x, y, x_smooth)
plt.plot(x_smooth, y_smooth, marker='o', markersize=3, linestyle=linestyle, label='impl-9-val-acc')

y = best_model_val_loss_1
x_sm = np.array(x)
y_sm = np.array(y)    
x_smooth = np.linspace(x_sm.min(), x_sm.max(), smoothing_factor)
y_smooth = spline(x, y, x_smooth)
plt.plot(x_smooth, y_smooth, marker='o', markersize=3, linestyle=linestyle, label='impl-9-val-loss')

plt.grid(True)
plt.legend(loc='upper center', 
           bbox_to_anchor=(0.5, -0.15),
           #prop={'size': 30},
           ncol=3,
           fancybox=True, 
           shadow=True
          )
plt.savefig('images\lstm_image_2_1_best_model_9_validation_loss_vs_validation_accuracy', bbox_inches='tight')
plt.show()
# Out:
# c:\python36\lib\site-packages\ipykernel_launcher.py:14: DeprecationWarning: `spline` is deprecated!
# spline is deprecated in scipy 0.19.0, use Bspline class instead.
#
# c:\python36\lib\site-packages\ipykernel_launcher.py:21: DeprecationWarning: `spline` is deprecated!
# spline is deprecated in scipy 0.19.0, use Bspline class instead.

# %%
smoothing_factor = 50
linestyle='-.'

#plt.figure(figsize=(30,15))
plt.title('Validation Loss vs. Validation Accuracy for LSTM Implementationimpl 8')
plt.xlabel('iterations')
plt.ylabel('validation accuracy')
x = x_axis_8

y = best_model_val_acc_2
x_sm = np.array(x)
y_sm = np.array(y)    
x_smooth = np.linspace(x_sm.min(), x_sm.max(), smoothing_factor)
y_smooth = spline(x, y, x_smooth)
plt.plot(x_smooth, y_smooth, marker='o', markersize=3, linestyle=linestyle, label='impl-8-val-acc')

y = best_model_val_loss_2
x_sm = np.array(x)
y_sm = np.array(y)    
x_smooth = np.linspace(x_sm.min(), x_sm.max(), smoothing_factor)
y_smooth = spline(x, y, x_smooth)
plt.plot(x_smooth, y_smooth, marker='o', markersize=3, linestyle=linestyle, label='impl-8-val-loss')

plt.grid(True)
plt.legend(loc='upper center', 
           bbox_to_anchor=(0.5, -0.15),
           #prop={'size': 30},
           ncol=3,
           fancybox=True, 
           shadow=True
          )
plt.savefig('images\lstm_image_2_2_best_model_8_validation_loss_vs_validation_accuracy', bbox_inches='tight')
plt.show()
# Out:
# c:\python36\lib\site-packages\ipykernel_launcher.py:14: DeprecationWarning: `spline` is deprecated!
# spline is deprecated in scipy 0.19.0, use Bspline class instead.
#
# c:\python36\lib\site-packages\ipykernel_launcher.py:21: DeprecationWarning: `spline` is deprecated!
# spline is deprecated in scipy 0.19.0, use Bspline class instead.

# %%
# comparing lstm model test accuracies (bar chart):

plt.rcdefaults()

plt.figure(figsize=(10,6))
objects = []
for i in range(0,len(model_list)):
    object_name = "impl-"+str(i+1)
    objects.append(object_name)
y_pos = np.arange(len(objects))
performance = test_acc_list ###

for a,b in zip(y_pos, performance):
    plt.text(a, b, str(b)+'%', horizontalalignment='center',verticalalignment='baseline')
    
plt.bar(y_pos, performance, align='center', alpha=0.9)
plt.xticks(y_pos, objects)
#plt.tick_params(axis='both', which='major', labelsize=10)
plt.tick_params(axis='x', which='major', labelsize=7)
plt.xlabel('lstm implementation no.')
plt.ylabel('test accuracy (%)')
plt.title('Comparison among LSTM Implementations Test Accuracies')
plt.savefig('images\lstm_image_3_comparing_lstm_model_test_accuracies_bar_chart.png', bbox_inches='tight')
plt.show()

# %%
# lstm_10_fold_cross_validation_on_model_8:
lstm_10_fold_cross_val_acc_list = [0.4870,0.4696,0.4870,0.4609,0.4696,0.4696,0.7130,0.7043,0.7913,0.8087,0.8435,0.8435,0.9478,0.9565,0.9565,0.9478,0.9391,0.9391,0.9826,0.9913,0.9913,0.9913,0.9913,0.9826,1.0000,1.0000,0.9913,1.0000,0.9826,0.9913]
lstm_10_fold_cross_val_loss_list = [0.209,0.247,0.102,0.156,0.084,0.020,0.056,0.122,0.020,0.042,0.010,0.002,0.006,0.005,0.003,0.001,0.001,0.005,0.001,0.002,0.001,0.002,0.000,0.000,0.001,0.000,0.000,0.000,0.002,0.000]

print(len(lstm_10_fold_cross_val_acc_list))
print(len(lstm_10_fold_cross_val_loss_list))
# Out:
# 30
# 30

# %%
smoothing_factor = 200
linestyle='-.'

#plt.figure(figsize=(30,15))
plt.title('Validation accuracy vs. Validation Loss for \nApplying 10 Fold Cross Validation on LSTM Model 8')
plt.xlabel('epochs')
plt.ylabel('accuracy')

x = [i for i in range (1,len(lstm_10_fold_cross_val_acc_list)+1)]
y = lstm_10_fold_cross_val_acc_list
plt.plot(x, y, marker='o', markersize=3, linestyle=linestyle, label='val-acc')

y = lstm_10_fold_cross_val_loss_list
plt.plot(x, y, marker='o', markersize=3, linestyle=linestyle, label='val-loss')

plt.grid(True)
plt.legend()
#plt.savefig('images\lstm_image_4_accuracy_vs_loss_for_10_fold_cross_validation.png', bbox_inches='tight')
plt.show()

# %%
smoothing_factor = 100
linestyle='-.'

#plt.figure(figsize=(30,15))
plt.title('Validation accuracy vs. Validation Loss for \nApplying 10 Fold Cross Validation on LSTM Implementation 8')
plt.xlabel('epochs')
plt.ylabel('accuracy')
x = [i for i in range (1,len(lstm_10_fold_cross_val_acc_list)+1)]

y = lstm_10_fold_cross_val_acc_list
x_sm = np.array(x)
y_sm = np.array(y)    
x_smooth = np.linspace(x_sm.min(), x_sm.max(), smoothing_factor)
y_smooth = spline(x, y, x_smooth)
plt.plot(x_smooth, y_smooth, marker='', markersize=1, linestyle=linestyle, label='val-acc')

y = lstm_10_fold_cross_val_loss_list
x_sm = np.array(x)
y_sm = np.array(y)    
x_smooth = np.linspace(x_sm.min(), x_sm.max(), smoothing_factor)
y_smooth = spline(x, y, x_smooth)
plt.plot(x_smooth, y_smooth, marker='', markersize=1, linestyle=linestyle, label='val-loss')

plt.grid(True)
plt.legend()
plt.savefig('images\lstm_image_4_accuracy_vs_loss_for_10_fold_cross_validation.png', bbox_inches='tight')
plt.show()
# Out:
# c:\python36\lib\site-packages\ipykernel_launcher.py:14: DeprecationWarning: `spline` is deprecated!
# spline is deprecated in scipy 0.19.0, use Bspline class instead.
#
# c:\python36\lib\site-packages\ipykernel_launcher.py:21: DeprecationWarning: `spline` is deprecated!
# spline is deprecated in scipy 0.19.0, use Bspline class instead.

# %%
# LSTM 10 FOLD CROSS VALIDATION MODEL ACCURACY::
lstm_10_fold_cross_val_folds_acc_list = [0.4870,0.4696,0.7913,0.8435,0.9565,0.9391,0.9913,0.9826,0.9913,0.9913]
lstm_10_fold_cross_val_model_acc = sum(lstm_10_fold_cross_val_folds_acc_list)/len(lstm_10_fold_cross_val_folds_acc_list)
print('LSTM MODEL - 10 FOLD CROSS VALIDATION MODEL ACCURACY =',lstm_10_fold_cross_val_model_acc)
# Out:
# LSTM MODEL - 10 FOLD CROSS VALIDATION MODEL ACCURACY = 0.84435
