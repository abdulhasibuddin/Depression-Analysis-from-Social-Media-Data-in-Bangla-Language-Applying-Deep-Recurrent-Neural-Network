# %%
# WITH STOP CHAR IMPLEMENTATION 9
# Courtesy: https://github.com/mchablani/deep-learning/blob/master/sentiment-rnn/Sentiment_RNN.ipynb
# Depression Analysis in Bangla with LSTM-RNN (without spaces before and after stop characters)::
# Two classes with balanced dataset (Total 1968 tweets):
# 1. Depressive (984 tweets)
# 2. Non-depressive (984 tweets)
# 1 depressive -> 1 non-depressive -> 1 depressive -> 1 non-depressive ...

'''
SELECT im2_tweets_depressive_nondepressive_balanced_rearranged.tweet
INTO OUTFILE "D:/EDUCATION/Machine & Deep Learning/Implementations/Implementation 2/im2_tweets_depressive_nondepressive_balanced_rearranged_text.txt" 
FROM im2_tweets_depressive_nondepressive_balanced_rearranged;
'''
# Out:
# '\nSELECT im2_tweets_depressive_nondepressive_balanced_rearranged.tweet\nINTO OUTFILE "D:/EDUCATION/Machine & Deep Learning/Implementations/Implementation 2/im2_tweets_depressive_nondepressive_balanced_rearranged_text.txt" \nFROM im2_tweets_depressive_nondepressive_balanced_rearranged;\n'

# %%
import numpy as np
import tensorflow as tf
from timeit import default_timer as timer
from collections import Counter
from string import punctuation
from google.colab import files

# %%
# Build the graph::

lstm_size = 128
lstm_layers = 5
batch_size = 1
learning_rate = 0.0001
epochs = 2

# %%
fileName = "9_with_stop"
checkpointName = "checkpoints/"+fileName+".ckpt"
print(checkpointName)
print(type(checkpointName))
# Out:
# checkpoints/9_with_stop.ckpt
# <class 'str'>

# %%
files.upload()
files.upload()

with open('2_tweets_depressive_nondepressive_balanced_rearranged_with_stop_char_text.txt', 'r', encoding="utf8") as f:
    tweets = f.read()
with open('2_tweets_depressive_nondepressive_balanced_rearranged_with_stop_char_labels.txt', 'r', encoding="utf8") as f:
    labels_org = f.read()
# Out:
#      <input type="file" id="files-7473109c-645a-4b87-a697-3a3e6c9ffc6b" name="files[]" multiple disabled />
#      <output id="result-7473109c-645a-4b87-a697-3a3e6c9ffc6b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 2_tweets_depressive_nondepressive_balanced_rearranged_with_stop_char_text.txt to 2_tweets_depressive_nondepressive_balanced_rearranged_with_stop_char_text (4).txt
#      <input type="file" id="files-fb14ed46-73e6-4044-8b93-c8332296cc0c" name="files[]" multiple disabled />
#      <output id="result-fb14ed46-73e6-4044-8b93-c8332296cc0c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 2_tweets_depressive_nondepressive_balanced_rearranged_with_stop_char_labels.txt to 2_tweets_depressive_nondepressive_balanced_rearranged_with_stop_char_labels (4).txt

# %%
# Data preprocessing::
#all_text = ''.join([c for c in tweets if c not in punctuation])
all_text = ''.join([c for c in tweets])
tweets = all_text.split('\n')

all_text = ' '.join(tweets)
words = all_text.split()

# %%
counts = Counter(words)
vocab = sorted(counts, key=counts.get, reverse=True)
vocab_to_int = {word: ii for ii, word in enumerate(vocab, 1)}

tweets_ints = []
for each in tweets:
    tweets_ints.append([vocab_to_int[word] for word in each.split()])

# %%
# Encoding the labels::
list_labels = []

for l in labels_org.split():
    if l == "depressive":
        list_labels.append(1)
    else:
        list_labels.append(0)
        
labels = np.array(list_labels)
print(len(labels))
# Out:
# 1968

# %%
tweets_lens = Counter([len(x) for x in tweets_ints])
print("Zero-length tweets: {}".format(tweets_lens[0]))
print("Maximum tweets length: {}".format(max(tweets_lens)))
# Out:
# Zero-length tweets: 1
# Maximum tweets length: 55

# %%
# Filter out that tweets with 0 length
tweets_ints = [r[0:200] for r in tweets_ints if len(r) > 0]

# %%
from collections import Counter
tweets_lens = Counter([len(x) for x in tweets_ints])
print("Zero-length tweets: {}".format(tweets_lens[0]))
print("Maximum tweet length: {}".format(max(tweets_lens)))
# Out:
# Zero-length tweets: 0
# Maximum tweet length: 55

# %%
seq_len = 200
features = np.zeros((len(tweets_ints), seq_len), dtype=int)
# print(features[:10,:100])
for i, row in enumerate(tweets_ints):
    features[i, -len(row):] = np.array(row)[:seq_len]
#features[:10,:100]

# %%
split_frac = 0.8

split_index = int(split_frac * len(features))

train_x, val_x = features[:split_index], features[split_index:] 
train_y, val_y = labels[:split_index], labels[split_index:]

split_frac = 0.5
split_index = int(split_frac * len(val_x))

val_x, test_x = val_x[:split_index], val_x[split_index:]
val_y, test_y = val_y[:split_index], val_y[split_index:]

print("\t\t\tFeature Shapes:")
print("Train set: \t\t{}".format(train_x.shape), 
      "\nValidation set: \t{}".format(val_x.shape),
      "\nTest set: \t\t{}".format(test_x.shape))
print("label set: \t\t{}".format(train_y.shape), 
      "\nValidation label set: \t{}".format(val_y.shape),
      "\nTest label set: \t\t{}".format(test_y.shape))
# Out:
# 			Feature Shapes:
# Train set: 		(1574, 200)
# Validation set: 	(197, 200)
# Test set: 		(197, 200)
# label set: 		(1574,)
# Validation label set: 	(197,)
# Test label set: 		(197,)

# %%
n_words = len(vocab_to_int) + 1 # Add 1 for 0 added to vocab

# Create the graph object
tf.reset_default_graph()
with tf.name_scope('inputs'):
    inputs_ = tf.placeholder(tf.int32, [None, None], name="inputs")
    labels_ = tf.placeholder(tf.int32, [None, None], name="labels")
    keep_prob = tf.placeholder(tf.float32, name="keep_prob")

# %%
# Size of the embedding vectors (number of units in the embedding layer)
embed_size = 300 

with tf.name_scope("Embeddings"):
    embedding = tf.Variable(tf.random_uniform((n_words, embed_size), -1, 1))
    embed = tf.nn.embedding_lookup(embedding, inputs_)

# %%
def lstm_cell():
    # Your basic LSTM cell
    lstm = tf.contrib.rnn.BasicLSTMCell(lstm_size, reuse=tf.get_variable_scope().reuse)
    # Add dropout to the cell
    return tf.contrib.rnn.DropoutWrapper(lstm, output_keep_prob=keep_prob)

with tf.name_scope("RNN_layers"):
    # Stack up multiple LSTM layers, for deep learning
    cell = tf.contrib.rnn.MultiRNNCell([lstm_cell() for _ in range(lstm_layers)])
    
    # Getting an initial state of all zeros
    initial_state = cell.zero_state(batch_size, tf.float32)
# Out:
# WARNING:tensorflow:From <ipython-input-16-678741cf60df>:3: BasicLSTMCell.__init__ (from tensorflow.python.ops.rnn_cell_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This class is deprecated, please use tf.nn.rnn_cell.LSTMCell, which supports all the feature this cell currently has. Please replace the existing code with tf.nn.rnn_cell.LSTMCell(name='basic_lstm_cell').

# %%
with tf.name_scope("RNN_forward"):
    outputs, final_state = tf.nn.dynamic_rnn(cell, embed, initial_state=initial_state)

# %%
# Output::

with tf.name_scope('predictions'):
    predictions = tf.contrib.layers.fully_connected(outputs[:, -1], 1, activation_fn=tf.sigmoid)
    tf.summary.histogram('predictions', predictions)
with tf.name_scope('cost'):
    cost = tf.losses.mean_squared_error(labels_, predictions)
    tf.summary.scalar('cost', cost)

with tf.name_scope('train'):
    optimizer = tf.train.AdamOptimizer(learning_rate).minimize(cost)

merged = tf.summary.merge_all()

# %%
# Validation accuracy::

with tf.name_scope('validation'):
    correct_pred = tf.equal(tf.cast(tf.round(predictions), tf.int32), labels_)
    accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32))

# %%
# Batching::

def get_batches(x, y, batch_size=100):
    
    n_batches = len(x)//batch_size
    x, y = x[:n_batches*batch_size], y[:n_batches*batch_size]
    for ii in range(0, len(x), batch_size):
        yield x[ii:ii+batch_size], y[ii:ii+batch_size]

# %%
# Training::

#epochs = 5
saver = tf.train.Saver()
start = timer()

with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    train_writer = tf.summary.FileWriter('./logs/tb/train', sess.graph)
    test_writer = tf.summary.FileWriter('./logs/tb/test', sess.graph)
    iteration = 1
    for e in range(1, epochs+1):
        state = sess.run(initial_state)
        
        for ii, (x, y) in enumerate(get_batches(train_x, train_y, batch_size), 1):
            feed = {inputs_: x,
                    labels_: y[:, None],
                    keep_prob: 0.5,
                    initial_state: state}
            summary, loss, state, _ = sess.run([merged, cost, final_state, optimizer], feed_dict=feed)
#             loss, state, _ = sess.run([cost, final_state, optimizer], feed_dict=feed)

            train_writer.add_summary(summary, iteration)
        
            if iteration%5==0:
                print("Epoch: {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Train loss: {:.3f}".format(loss))

            if iteration%25==0:
                val_acc = []
                val_state = sess.run(cell.zero_state(batch_size, tf.float32))
                for x, y in get_batches(val_x, val_y, batch_size):
                    feed = {inputs_: x,
                            labels_: y[:, None],
                            keep_prob: 1,
                            initial_state: val_state}
#                     batch_acc, val_state = sess.run([accuracy, final_state], feed_dict=feed)
                    summary, batch_acc, val_state = sess.run([merged, accuracy, final_state], feed_dict=feed)
                    val_acc.append(batch_acc)
                print("Val acc: {:.3f}".format(np.mean(val_acc)))
            iteration +=1
            test_writer.add_summary(summary, iteration)
            saver.save(sess, checkpointName)
#            tensorboard = TensorBoard(log_dir="logs/tweet_5000_all_sentiments_six_classes-{}".format(int(time.time())))
    saver.save(sess, checkpointName)
    
duration = timer() - start
print('Time elasped =',duration,'sec(s)')
# Out:
# Epoch: 1/2 Iteration: 5 Train loss: 0.253
# Epoch: 1/2 Iteration: 10 Train loss: 0.251
# Epoch: 1/2 Iteration: 15 Train loss: 0.262
# Epoch: 1/2 Iteration: 20 Train loss: 0.246
# Epoch: 1/2 Iteration: 25 Train loss: 0.273
# Val acc: 0.543
# Epoch: 1/2 Iteration: 30 Train loss: 0.239
# Epoch: 1/2 Iteration: 35 Train loss: 0.292
# Epoch: 1/2 Iteration: 40 Train loss: 0.238
# Epoch: 1/2 Iteration: 45 Train loss: 0.261
# Epoch: 1/2 Iteration: 50 Train loss: 0.253
# Val acc: 0.513
# Epoch: 1/2 Iteration: 55 Train loss: 0.259
# Epoch: 1/2 Iteration: 60 Train loss: 0.238
# Epoch: 1/2 Iteration: 65 Train loss: 0.261
# Epoch: 1/2 Iteration: 70 Train loss: 0.250
# Epoch: 1/2 Iteration: 75 Train loss: 0.274
# Epoch: 2/2 Iteration: 2955 Train loss: 0.019
# Epoch: 2/2 Iteration: 2960 Train loss: 0.110
# Epoch: 2/2 Iteration: 2965 Train loss: 0.082
# Epoch: 2/2 Iteration: 2970 Train loss: 0.111
# Epoch: 2/2 Iteration: 2975 Train loss: 0.041
# Val acc: 0.741
# Epoch: 2/2 Iteration: 2980 Train loss: 0.140
# Epoch: 2/2 Iteration: 2985 Train loss: 0.299
# Epoch: 2/2 Iteration: 2990 Train loss: 0.181
# Epoch: 2/2 Iteration: 2995 Train loss: 0.110
# Epoch: 2/2 Iteration: 3000 Train loss: 0.189
# Val acc: 0.751
# Epoch: 2/2 Iteration: 3005 Train loss: 0.123
# Epoch: 2/2 Iteration: 3010 Train loss: 0.191
# Epoch: 2/2 Iteration: 3015 Train loss: 0.292
# Epoch: 2/2 Iteration: 3020 Train loss: 0.651
# Epoch: 2/2 Iteration: 3025 Train loss: 0.098
# Val acc: 0.766
# Epoch: 2/2 Iteration: 3030 Train loss: 0.031
# Epoch: 2/2 Iteration: 3035 Train loss: 0.527
# Epoch: 2/2 Iteration: 3040 Train loss: 0.052
# Epoch: 2/2 Iteration: 3045 Train loss: 0.157
# Epoch: 2/2 Iteration: 3050 Train loss: 0.137
# Val acc: 0.746
# Epoch: 2/2 Iteration: 3055 Train loss: 0.344
# Epoch: 2/2 Iteration: 3060 Train loss: 0.072
# Epoch: 2/2 Iteration: 3065 Train loss: 0.397
# Epoch: 2/2 Iteration: 3070 Train loss: 0.062
# Epoch: 2/2 Iteration: 3075 Train loss: 0.187
# Val acc: 0.695
# Epoch: 2/2 Iteration: 3080 Train loss: 0.104
# Epoch: 2/2 Iteration: 3085 Train loss: 0.022
# Epoch: 2/2 Iteration: 3090 Train loss: 0.878
# Epoch: 2/2 Iteration: 3095 Train loss: 0.300
# Epoch: 2/2 Iteration: 3100 Train loss: 0.052
# Val acc: 0.701
# Epoch: 2/2 Iteration: 3105 Train loss: 0.114
# Epoch: 2/2 Iteration: 3110 Train loss: 0.238
# Epoch: 2/2 Iteration: 3115 Train loss: 0.002
# Epoch: 2/2 Iteration: 3120 Train loss: 0.132
# Epoch: 2/2 Iteration: 3125 Train loss: 0.003
# Val acc: 0.701
# Epoch: 2/2 Iteration: 3130 Train loss: 0.680
# Epoch: 2/2 Iteration: 3135 Train loss: 0.007
# Epoch: 2/2 Iteration: 3140 Train loss: 0.091
# Epoch: 2/2 Iteration: 3145 Train loss: 0.004
# Time elasped = 20551.058140008998 sec(s)

# %%
# Testing::

test_acc = []
with tf.Session() as sess:
    saver.restore(sess, checkpointName)
    test_state = sess.run(cell.zero_state(batch_size, tf.float32))
    for ii, (x, y) in enumerate(get_batches(test_x, test_y, batch_size), 1):
        feed = {inputs_: x,
                labels_: y[:, None],
                keep_prob: 1,
                initial_state: test_state}
        batch_acc, test_state = sess.run([accuracy, final_state], feed_dict=feed)
        test_acc.append(batch_acc)
    print("Test accuracy: {:.3f}".format(np.mean(test_acc)))
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints/9_with_stop.ckpt
# Test accuracy: 0.701
